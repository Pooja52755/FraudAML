# %%
import polars as pl
from config import DATA_PATH

# %%
# Load raw transaction and account files directly from Kaggle cache
trx = pl.scan_csv(DATA_PATH + '/HI-Small_Trans.csv')
act = pl.scan_csv(DATA_PATH + '/HI-Small_accounts.csv')

# %%
rename_map = {
    'Timestamp': 'timestamp',
    'From Bank': 'from_bank',
    'Account': 'from_account',
    'To Bank': 'to_bank',
    'Account.1': 'to_account',
    'Account_duplicated_0': 'to_account',
    'Amount Received': 'amount_rcv',
    'Receiving Currency': 'currency_rcv',
    'Amount Paid': 'amount_paid',
    'Payment Currency': 'currency_paid',
    'Payment Format': 'payment_format',
    'Is Laundering': 'is_laundering',
    'Bank Name': 'bank_name', 
    'Bank ID': 'bank_id', 
    'Account Number': 'account_id', 
    'Entity ID': 'entity_id', 
    'Entity Name': 'entity_name'
}

# Rename columns to snake_case — same map as in the feature engineering notebook
existing = {k: v for k, v in rename_map.items() if k in trx.collect_schema().names()}
trx = trx.rename(existing)

# %%
# Integer encoding for the 8 laundering motifs documented in HI-Small_Patterns.txt
# NONE (-1) is assigned to transactions not belonging to any documented pattern
pattern_map = {
    "FAN-IN":         0,
    "FAN-OUT":        1,
    "GATHER-SCATTER": 2,
    "SCATTER-GATHER": 3,
    "CYCLE":          4,
    "STACK":          5,
    "RANDOM":         6,
    "BIPARTITE":      7,
    "NONE":           -1,
}

# Initialise all transactions as NONE — patterns will be assigned in the cells below
trx = trx.with_columns(
    pl.lit(-1).alias("pattern")
)

# %% [markdown]
# ### Fan-out

# %%
trx = trx.with_columns(
    pl.when(
        (pl.col("from_bank") == 21174) &
        (pl.col("from_account") == "800737690") &
        (pl.col("is_laundering") == 1)

    ).then(pl.lit(1))  # FAN-OUT

    .when(
        (pl.col("from_bank") == 116) &
        (pl.col("from_account") == "80F1AF380") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 241079) &
        (pl.col("from_account") == "80EF0F190") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 225734) &
        (pl.col("from_account") == "8095AF170") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 10) &
        (pl.col("from_account") == "8001BB380") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 15) &
        (pl.col("from_account") == "803B24460") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 2843) &
        (pl.col("from_account") == "800A4B110") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 15231) &
        (pl.col("from_account") == "80266F880") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 24515) &
        (pl.col("from_account") == "80EBB2100") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 5) &
        (pl.col("from_account") == "80769F1A0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 150240) &
        (pl.col("from_account") == "812D22980") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 148350) &
        (pl.col("from_account") == "812D0C3C0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 113523) &
        (pl.col("from_account") == "8054100E0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 148350) &
        (pl.col("from_account") == "811FFF630") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 11107) &
        (pl.col("from_account") == "80338EC60") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 22155) &
        (pl.col("from_account") == "808D89450") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
    .when(
        (pl.col("from_bank") == 219969) &
        (pl.col("from_account") == "80AC120A0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 222664) &
        (pl.col("from_account") == "80B7973F0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 22) &
        (pl.col("from_account") == "800241D60") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 117) &
        (pl.col("from_account") == "80E5157A0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 122545) &
        (pl.col("from_account") == "8120633F0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 1299) &
        (pl.col("from_account") == "8009D3030") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
    .when(
        (pl.col("from_bank") == 49365) &
        (pl.col("from_account") == "812A09D40") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 21918) &
        (pl.col("from_account") == "8089DC420") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 9679) &
        (pl.col("from_account") == "80452D470") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 121) &
        (pl.col("from_account") == "8000E1590") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 210431) &
        (pl.col("from_account") == "809BFD6B0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))


    .when(
        (pl.col("from_bank") == 119) &
        (pl.col("from_account") == "812A09CF0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 23691) &
        (pl.col("from_account") == "8021353D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))


    .when(
        (pl.col("from_bank") == 13067) &
        (pl.col("from_account") == "80B76EEA0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 229558) &
        (pl.col("from_account") == "80E11A500") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 11128) &
        (pl.col("from_account") == "8045F4500") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 21611) &
        (pl.col("from_account") == "808D6F2D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 223) &
        (pl.col("from_account") == "811A4DBD0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 20) &
        (pl.col("from_account") == "800195070") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 214749) &
        (pl.col("from_account") == "805DB7F20") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 249176) &
        (pl.col("from_account") == "812A70ED0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 25075) &
        (pl.col("from_account") == "802873390") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 50202) &
        (pl.col("from_account") == "812D129C0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 232391) &
        (pl.col("from_account") == "80C8966E0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 231212) &
        (pl.col("from_account") == "80ED002D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))

    .when(
        (pl.col("from_bank") == 4403) &
        (pl.col("from_account") == "80F962B10") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .when(
        (pl.col("from_bank") == 20) &
        (pl.col("from_account") == "8001C97D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(1))
        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 1)
    .select(["from_bank", "from_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as fan-out: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as fan-out: 478
# All are laundering: True
# shape: (10, 4)
# ┌───────────┬──────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═══════════════╪═════════╡
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# │ 21174     ┆ 800737690    ┆ 1             ┆ 1       │
# └───────────┴──────────────┴───────────────┴─────────┘

# %% [markdown]
# ### Fan-in

# %%
trx = trx.with_columns(
    pl.when(
        (pl.col("to_bank") == 119) &
        (pl.col("to_account") == "811C597B0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))  # FAN-IN

    .when(
        (pl.col("to_bank") == 48308) &
        (pl.col("to_account") == "811ED7DF0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 1362) &
        (pl.col("to_account") == "8001ECD70") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))
    .when(
        (pl.col("to_bank") == 148350) &
        (pl.col("to_account") == "812D0C3C0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 49365) &
        (pl.col("to_account") == "812A09D40") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 21918) &
        (pl.col("to_account") == "8053168D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 26174) &
        (pl.col("to_account") == "809CC4600") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 111764) &
        (pl.col("to_account") == "807DD0FB0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 19535) &
        (pl.col("to_account") == "80B18E250") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 1124) &
        (pl.col("to_account") == "800852F80") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 25866) &
        (pl.col("to_account") == "80E27AA10") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 12735) &
        (pl.col("to_account") == "801658A00") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 13145) &
        (pl.col("to_account") == "80145D800") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 48309) &
        (pl.col("to_account") == "811C599A0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))


    .when(
        (pl.col("to_bank") == 29814) &
        (pl.col("to_account") == "80BB289A0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 7042) &
        (pl.col("to_account") == "803173180") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 1547) &
        (pl.col("to_account") == "8028F2650") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 119) &
        (pl.col("to_account") == "812A09CF0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 23) &
        (pl.col("to_account") == "80017F180") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))


    .when(
        (pl.col("to_bank") == 410) &
        (pl.col("to_account") == "80098DC70") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 148350) &
        (pl.col("to_account") == "811FFF630") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 11056) &
        (pl.col("to_account") == "800E3D880") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 18511) &
        (pl.col("to_account") == "811CCBB50") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 19740) &
        (pl.col("to_account") == "8047B9AD0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 14325) &
        (pl.col("to_account") == "801A21E40") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 17863) &
        (pl.col("to_account") == "810C289B0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 150240) &
        (pl.col("to_account") == "812D22980") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 19888) &
        (pl.col("to_account") == "8079DDC30") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))
        
    .when(
        (pl.col("to_bank") == 11157) &
        (pl.col("to_account") == "801658CE0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 222) &
        (pl.col("to_account") == "811B83280") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 27755) &
        (pl.col("to_account") == "80A2DF610") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 11) &
        (pl.col("to_account") == "8001D5B50") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 49508) &
        (pl.col("to_account") == "812A70E80") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))
    .when(
        (pl.col("to_bank") == 23691) &
        (pl.col("to_account") == "8021353D0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))


    .when(
        (pl.col("to_bank") == 33245) &
        (pl.col("to_account") == "80EBE7E20") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 12) &
        (pl.col("to_account") == "8006757B0") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 225263) &
        (pl.col("to_account") == "80E6BFD50") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 22) &
        (pl.col("to_account") == "8000FC360") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

    .when(
        (pl.col("to_bank") == 41407) &
        (pl.col("to_account") == "80F454910") &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(0))

        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 0)
    .select(["to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as fan-in: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as fan-in: 483
# All are laundering: True
# shape: (10, 4)
# ┌─────────┬────────────┬───────────────┬─────────┐
# │ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═════════╪════════════╪═══════════════╪═════════╡
# │ 48309   ┆ 811C599A0  ┆ 1             ┆ 0       │
# │ 48309   ┆ 811C599A0  ┆ 1             ┆ 0       │
# │ 48309   ┆ 811C599A0  ┆ 1             ┆ 0       │
# │ 48309   ┆ 811C599A0  ┆ 1             ┆ 0       │
# │ 119     ┆ 811C597B0  ┆ 1             ┆ 0       │
# │ 148350  ┆ 812D0C3C0  ┆ 1             ┆ 0       │
# │ 148350  ┆ 812D0C3C0  ┆ 1             ┆ 0       │
# │ 148350  ┆ 811FFF630  ┆ 1             ┆ 0       │
# │ 119     ┆ 811C597B0  ┆ 1             ┆ 0       │
# │ 119     ┆ 811C597B0  ┆ 1             ┆ 0       │
# └─────────┴────────────┴───────────────┴─────────┘

# %% [markdown]
# ### Gather-scatter

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_bank") == 48309) & (pl.col("from_account") == "811C599A0")) |
            ((pl.col("to_bank") == 48309) & (pl.col("to_account") == "811C599A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))  # GATHER-SCATTER
    .when(
        (
            ((pl.col("from_bank") == 241869) & (pl.col("from_account") == "80F390FC0")) |
            ((pl.col("to_bank") == 241869) & (pl.col("to_account") == "80F390FC0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))
    .when(
        (
            ((pl.col("from_bank") == 148350) & (pl.col("from_account") == "812D0C3C0")) |
            ((pl.col("to_bank") == 148350) & (pl.col("to_account") == "812D0C3C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))
    .when(
        (
            ((pl.col("from_bank") == 12) & (pl.col("from_account") == "800054B70")) |
            ((pl.col("to_bank") == 12) & (pl.col("to_account") == "800054B70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 211) & (pl.col("from_account") == "808E44B10")) |
            ((pl.col("to_bank") == 211) & (pl.col("to_account") == "808E44B10"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 135981) & (pl.col("from_account") == "80F984C70")) |
            ((pl.col("to_bank") == 135981) & (pl.col("to_account") == "80F984C70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 15231) & (pl.col("from_account") == "80266F880")) |
            ((pl.col("to_bank") == 15231) & (pl.col("to_account") == "80266F880"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 19318) & (pl.col("from_account") == "8106B1750")) |
            ((pl.col("to_bank") == 19318) & (pl.col("to_account") == "8106B1750"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 214615) & (pl.col("from_account") == "8075AC7C0")) |
            ((pl.col("to_bank") == 214615) & (pl.col("to_account") == "8075AC7C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 1420) & (pl.col("from_account") == "80437D050")) |
            ((pl.col("to_bank") == 1420) & (pl.col("to_account") == "80437D050"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 12) & (pl.col("from_account") == "8010D4440")) |
            ((pl.col("to_bank") == 12) & (pl.col("to_account") == "8010D4440"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 26302) & (pl.col("from_account") == "809DACA80")) |
            ((pl.col("to_bank") == 26302) & (pl.col("to_account") == "809DACA80"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 139342) & (pl.col("from_account") == "80EB1E930")) |
            ((pl.col("to_bank") == 139342) & (pl.col("to_account") == "80EB1E930"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 8771) & (pl.col("from_account") == "80C6F48A0")) |
            ((pl.col("to_bank") == 8771) & (pl.col("to_account") == "80C6F48A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 3051) & (pl.col("from_account") == "804282480")) |
            ((pl.col("to_bank") == 3051) & (pl.col("to_account") == "804282480"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 222) & (pl.col("from_account") == "811D80C30")) |
            ((pl.col("to_bank") == 222) & (pl.col("to_account") == "811D80C30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 21749) & (pl.col("from_account") == "80154AAF0")) |
            ((pl.col("to_bank") == 21749) & (pl.col("to_account") == "80154AAF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 23289) & (pl.col("from_account") == "808839F70")) |
            ((pl.col("to_bank") == 23289) & (pl.col("to_account") == "808839F70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 21749) & (pl.col("from_account") == "801F05EF0")) |
            ((pl.col("to_bank") == 21749) & (pl.col("to_account") == "801F05EF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 12381) & (pl.col("from_account") == "803C75EA0")) |
            ((pl.col("to_bank") == 12381) & (pl.col("to_account") == "803C75EA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 19329) & (pl.col("from_account") == "808B1C350")) |
            ((pl.col("to_bank") == 19329) & (pl.col("to_account") == "808B1C350"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 11) & (pl.col("from_account") == "800924840")) |
            ((pl.col("to_bank") == 11) & (pl.col("to_account") == "800924840"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))
    .when(
        (
            ((pl.col("from_bank") == 12963) & (pl.col("from_account") == "8016C37F0")) |
            ((pl.col("to_bank") == 12963) & (pl.col("to_account") == "8016C37F0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))
    .when(
        (
            ((pl.col("from_bank") == 29685) & (pl.col("from_account") == "80F576BB0")) |
            ((pl.col("to_bank") == 29685) & (pl.col("to_account") == "80F576BB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 14804) & (pl.col("from_account") == "806698470")) |
            ((pl.col("to_bank") == 14804) & (pl.col("to_account") == "806698470"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 28) & (pl.col("from_account") == "8000B8AB0")) |
            ((pl.col("to_bank") == 28) & (pl.col("to_account") == "8000B8AB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 4726) & (pl.col("from_account") == "802E2AD70")) |
            ((pl.col("to_bank") == 4726) & (pl.col("to_account") == "802E2AD70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 213952) & (pl.col("from_account") == "80794B6F0")) |
            ((pl.col("to_bank") == 213952) & (pl.col("to_account") == "80794B6F0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 21745) & (pl.col("from_account") == "801E11270")) |
            ((pl.col("to_bank") == 21745) & (pl.col("to_account") == "801E11270"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 19) & (pl.col("from_account") == "8000AEDD0")) |
            ((pl.col("to_bank") == 19) & (pl.col("to_account") == "8000AEDD0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 1412) & (pl.col("from_account") == "8051E3B20")) |
            ((pl.col("to_bank") == 1412) & (pl.col("to_account") == "8051E3B20"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 220) & (pl.col("from_account") == "8012CD590")) |
            ((pl.col("to_bank") == 220) & (pl.col("to_account") == "8012CD590"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 15) & (pl.col("from_account") == "803DE4A90")) |
            ((pl.col("to_bank") == 15) & (pl.col("to_account") == "803DE4A90"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 21611) & (pl.col("from_account") == "8051B3BF0")) |
            ((pl.col("to_bank") == 21611) & (pl.col("to_account") == "8051B3BF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 118) & (pl.col("from_account") == "811B6E170")) |
            ((pl.col("to_bank") == 118) & (pl.col("to_account") == "811B6E170"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 9371) & (pl.col("from_account") == "8043A0FB0")) |
            ((pl.col("to_bank") == 9371) & (pl.col("to_account") == "8043A0FB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 29404) & (pl.col("from_account") == "8041A3440")) |
            ((pl.col("to_bank") == 29404) & (pl.col("to_account") == "8041A3440"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))

    .when(
        (
            ((pl.col("from_bank") == 1) & (pl.col("from_account") == "80C356B30")) |
            ((pl.col("to_bank") == 1) & (pl.col("to_account") == "80C356B30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(2))
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 2)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as gather-scatter: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as gather-scatter: 798
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 119       ┆ 811C597B0    ┆ 48309   ┆ 811C599A0  ┆ 1             ┆ 2       │
# │ 150240    ┆ 812D22980    ┆ 48309   ┆ 811C599A0  ┆ 1             ┆ 2       │
# │ 222       ┆ 811B83280    ┆ 48309   ┆ 811C599A0  ┆ 1             ┆ 2       │
# │ 48309     ┆ 811C599A0    ┆ 48309   ┆ 811C599A0  ┆ 1             ┆ 2       │
# │ 48309     ┆ 811C599A0    ┆ 119     ┆ 811C597B0  ┆ 1             ┆ 2       │
# │ 12963     ┆ 80296CA20    ┆ 241869  ┆ 80F390FC0  ┆ 1             ┆ 2       │
# ...

# %% [markdown]
# ### Scatter-gather

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_bank") == 213952) & (pl.col("from_account") == "808338D40")) |
            ((pl.col("to_bank") == 26442) & (pl.col("to_account") == "80AEBECB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))  # SCATTER-GATHER

    .when(
        (
            ((pl.col("from_bank") == 908) & (pl.col("from_account") == "800957210")) |
            ((pl.col("to_bank") == 1665) & (pl.col("to_account") == "80054CAB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 111631) & (pl.col("from_account") == "80A38F130")) |
            ((pl.col("to_bank") == 10404) & (pl.col("to_account") == "807AD0240"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 21745) & (pl.col("from_account") == "803366440")) |
            ((pl.col("to_bank") == 112931) & (pl.col("to_account") == "805D4C850"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 124331) & (pl.col("from_account") == "8100B34B0")) |
            ((pl.col("to_bank") == 29064) & (pl.col("to_account") == "80A99BDA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 135403) & (pl.col("from_account") == "80E2226E0")) |
            ((pl.col("to_bank") == 2952) & (pl.col("to_account") == "8019A2650"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 213) & (pl.col("from_account") == "80C93DF00")) |
            ((pl.col("to_bank") == 13078) & (pl.col("to_account") == "8053B01E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 19329) & (pl.col("from_account") == "805A91C10")) |
            ((pl.col("to_bank") == 23842) & (pl.col("to_account") == "8017D32A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 12979) & (pl.col("from_account") == "80D9A9270")) |
            ((pl.col("to_bank") == 140257) & (pl.col("to_account") == "80F0169B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 20486) & (pl.col("from_account") == "807EF78D0")) |
            ((pl.col("to_bank") == 139793) & (pl.col("to_account") == "80EB1AA20"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 238845) & (pl.col("from_account") == "80F499130")) |
            ((pl.col("to_bank") == 701) & (pl.col("to_account") == "8013F0350"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 1267) & (pl.col("from_account") == "8030004E0")) |
            ((pl.col("to_bank") == 222664) & (pl.col("to_account") == "80D7EC5F0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 11405) & (pl.col("from_account") == "800EE6B70")) |
            ((pl.col("to_bank") == 1024) & (pl.col("to_account") == "80098A3D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 27241) & (pl.col("from_account") == "803BEF990")) |
            ((pl.col("to_bank") == 8823) & (pl.col("to_account") == "8079C0A30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 18196) & (pl.col("from_account") == "80B1BF360")) |
            ((pl.col("to_bank") == 111141) & (pl.col("to_account") == "80C5219E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 5836) & (pl.col("from_account") == "80DEE3B40")) |
            ((pl.col("to_bank") == 15085) & (pl.col("to_account") == "81121FAB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 7675) & (pl.col("from_account") == "8093BA230")) |
            ((pl.col("to_bank") == 210261) & (pl.col("to_account") == "803B8BFC0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 5) & (pl.col("from_account") == "807E7A050")) |
            ((pl.col("to_bank") == 1547) & (pl.col("to_account") == "801C95950"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 13554) & (pl.col("from_account") == "8018BB080")) |
            ((pl.col("to_bank") == 908) & (pl.col("to_account") == "801A655B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 11030) & (pl.col("from_account") == "80CB65920")) |
            ((pl.col("to_bank") == 1292) & (pl.col("to_account") == "80AE68D00"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 2824) & (pl.col("from_account") == "80200E890")) |
            ((pl.col("to_bank") == 117070) & (pl.col("to_account") == "807065AD0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 23842) & (pl.col("from_account") == "8019C0990")) |
            ((pl.col("to_bank") == 21258) & (pl.col("to_account") == "8028E8460"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 2591) & (pl.col("from_account") == "800AEAC00")) |
            ((pl.col("to_bank") == 22) & (pl.col("to_account") == "8000EE420"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 15040) & (pl.col("from_account") == "8111CA220")) |
            ((pl.col("to_bank") == 10) & (pl.col("to_account") == "80CCC1960"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 13862) & (pl.col("from_account") == "8078765D0")) |
            ((pl.col("to_bank") == 1601) & (pl.col("to_account") == "80340DCF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 20) & (pl.col("from_account") == "8010CDC50")) |
            ((pl.col("to_bank") == 1490) & (pl.col("to_account") == "800B65420"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 48308) & (pl.col("from_account") == "811EDA7A0")) |
            ((pl.col("to_bank") == 119) & (pl.col("to_account") == "81235E8B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 7548) & (pl.col("from_account") == "8040AE4F0")) |
            ((pl.col("to_bank") == 11128) & (pl.col("to_account") == "80465E020"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 235509) & (pl.col("from_account") == "80CEC5700")) |
            ((pl.col("to_bank") == 1) & (pl.col("to_account") == "8029FC480"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

    .when(
        (
            ((pl.col("from_bank") == 1267) & (pl.col("from_account") == "8007C7660")) |
            ((pl.col("to_bank") == 117) & (pl.col("to_account") == "80F219920"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(3))

        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 3)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as scatter-gather: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as scatter-gather: 593
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 213952    ┆ 808338D40    ┆ 25534   ┆ 8095B6AF0  ┆ 1             ┆ 3       │
# │ 25534     ┆ 8095B6AF0    ┆ 26442   ┆ 80AEBECB0  ┆ 1             ┆ 3       │
# │ 213952    ┆ 808338D40    ┆ 20      ┆ 803892E30  ┆ 1             ┆ 3       │
# │ 20        ┆ 803892E30    ┆ 26442   ┆ 80AEBECB0  ┆ 1             ┆ 3       │
# │ 213952    ┆ 808338D40    ┆ 213952  ┆ 806D47B10  ┆ 1             ┆ 3       │
# │ 213952    ┆ 806D47B10    ┆ 26442   ┆ 80AEBECB0  ┆ 1             ┆ 3       │
# ...

# %% [markdown]
# ### Cycle

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_account") == "8013C4030") | (pl.col("to_account") == "8013C4030")) |
            ((pl.col("from_account") == "80BC62F10") | (pl.col("to_account") == "80BC62F10")) |
            ((pl.col("from_account") == "80F025640") | (pl.col("to_account") == "80F025640")) |
            ((pl.col("from_account") == "80FD27570") | (pl.col("to_account") == "80FD27570")) |
            ((pl.col("from_account") == "8090E8EB0") | (pl.col("to_account") == "8090E8EB0")) |
            ((pl.col("from_account") == "804ABCE90") | (pl.col("to_account") == "804ABCE90")) |
            ((pl.col("from_account") == "805494C30") | (pl.col("to_account") == "805494C30")) |
            ((pl.col("from_account") == "801B949C0") | (pl.col("to_account") == "801B949C0")) |
            ((pl.col("from_account") == "803DE1580") | (pl.col("to_account") == "803DE1580")) |
            ((pl.col("from_account") == "80ACEE280") | (pl.col("to_account") == "80ACEE280"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))  # CYCLE

    .when(
        (
            ((pl.col("from_account") == "80DED0520") | (pl.col("to_account") == "80DED0520")) |
            ((pl.col("from_account") == "80A451570") | (pl.col("to_account") == "80A451570")) |
            ((pl.col("from_account") == "80D179410") | (pl.col("to_account") == "80D179410")) |
            ((pl.col("from_account") == "80A976860") | (pl.col("to_account") == "80A976860")) |
            ((pl.col("from_account") == "80BAEB330") | (pl.col("to_account") == "80BAEB330")) |
            ((pl.col("from_account") == "806D399E0") | (pl.col("to_account") == "806D399E0")) |
            ((pl.col("from_account") == "80BE74FC0") | (pl.col("to_account") == "80BE74FC0")) |
            ((pl.col("from_account") == "80EA93ED0") | (pl.col("to_account") == "80EA93ED0")) |
            ((pl.col("from_account") == "8079EC940") | (pl.col("to_account") == "8079EC940")) |
            ((pl.col("from_account") == "80F93F560") | (pl.col("to_account") == "80F93F560"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))


    .when(
        (
            ((pl.col("from_account") == "802125640") | (pl.col("to_account") == "802125640")) |
            ((pl.col("from_account") == "800BFED10") | (pl.col("to_account") == "800BFED10")) |
            ((pl.col("from_account") == "80150CB00") | (pl.col("to_account") == "80150CB00")) |
            ((pl.col("from_account") == "801309540") | (pl.col("to_account") == "801309540")) |
            ((pl.col("from_account") == "800463160") | (pl.col("to_account") == "800463160")) |
            ((pl.col("from_account") == "8009FD760") | (pl.col("to_account") == "8009FD760")) |
            ((pl.col("from_account") == "8013DB9A0") | (pl.col("to_account") == "8013DB9A0")) |
            ((pl.col("from_account") == "8003A56A0") | (pl.col("to_account") == "8003A56A0")) |
            ((pl.col("from_account") == "800776AF0") | (pl.col("to_account") == "800776AF0")) |
            ((pl.col("from_account") == "8018245C0") | (pl.col("to_account") == "8018245C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880")) |
            ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))


    .when(
        (
            ((pl.col("from_account") == "802528AE0") | (pl.col("to_account") == "802528AE0")) |
            ((pl.col("from_account") == "8034D1800") | (pl.col("to_account") == "8034D1800")) |
            ((pl.col("from_account") == "8037EB780") | (pl.col("to_account") == "8037EB780"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))


    .when(
        (
            ((pl.col("from_account") == "8011D4F20") | (pl.col("to_account") == "8011D4F20")) |
            ((pl.col("from_account") == "811A9BD00") | (pl.col("to_account") == "811A9BD00")) |
            ((pl.col("from_account") == "80FBCC760") | (pl.col("to_account") == "80FBCC760")) |
            ((pl.col("from_account") == "80A709C90") | (pl.col("to_account") == "80A709C90")) |
            ((pl.col("from_account") == "80CA77970") | (pl.col("to_account") == "80CA77970")) |
            ((pl.col("from_account") == "80E11E6A0") | (pl.col("to_account") == "80E11E6A0")) |
            ((pl.col("from_account") == "8035765E0") | (pl.col("to_account") == "8035765E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80F2C2FA0") | (pl.col("to_account") == "80F2C2FA0")) |
            ((pl.col("from_account") == "8095F9B40") | (pl.col("to_account") == "8095F9B40"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "803A568D0") | (pl.col("to_account") == "803A568D0")) |
            ((pl.col("from_account") == "8012F9500") | (pl.col("to_account") == "8012F9500")) |
            ((pl.col("from_account") == "8102CA2C0") | (pl.col("to_account") == "8102CA2C0")) |
            ((pl.col("from_account") == "8040FAF80") | (pl.col("to_account") == "8040FAF80")) |
            ((pl.col("from_account") == "80AC28E60") | (pl.col("to_account") == "80AC28E60")) |
            ((pl.col("from_account") == "80CF37D80") | (pl.col("to_account") == "80CF37D80"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80E12A290") | (pl.col("to_account") == "80E12A290")) |
            ((pl.col("from_account") == "804DE3CB0") | (pl.col("to_account") == "804DE3CB0")) |
            ((pl.col("from_account") == "811F41AC0") | (pl.col("to_account") == "811F41AC0")) |
            ((pl.col("from_account") == "8042BFA00") | (pl.col("to_account") == "8042BFA00"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))


    .when(
        (
            ((pl.col("from_account") == "80ECAB9A0") | (pl.col("to_account") == "80ECAB9A0")) |
            ((pl.col("from_account") == "8087D80F0") | (pl.col("to_account") == "8087D80F0")) |
            ((pl.col("from_account") == "806C30AA0") | (pl.col("to_account") == "806C30AA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8049EE130") | (pl.col("to_account") == "8049EE130")) |
            ((pl.col("from_account") == "80C9CEC30") | (pl.col("to_account") == "80C9CEC30")) |
            ((pl.col("from_account") == "809F265F0") | (pl.col("to_account") == "809F265F0")) |
            ((pl.col("from_account") == "8087B9410") | (pl.col("to_account") == "8087B9410")) |
            ((pl.col("from_account") == "804853540") | (pl.col("to_account") == "804853540"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "801C602A0") | (pl.col("to_account") == "801C602A0")) |
            ((pl.col("from_account") == "80408AC50") | (pl.col("to_account") == "80408AC50"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80EBD88F0") | (pl.col("to_account") == "80EBD88F0")) |
            ((pl.col("from_account") == "809936360") | (pl.col("to_account") == "809936360")) |
            ((pl.col("from_account") == "807BFE2C0") | (pl.col("to_account") == "807BFE2C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80E9CE540") | (pl.col("to_account") == "80E9CE540")) |
            ((pl.col("from_account") == "808FADF50") | (pl.col("to_account") == "808FADF50")) |
            ((pl.col("from_account") == "8052D0490") | (pl.col("to_account") == "8052D0490")) |
            ((pl.col("from_account") == "805565C40") | (pl.col("to_account") == "805565C40")) |
            ((pl.col("from_account") == "806ABE0A0") | (pl.col("to_account") == "806ABE0A0")) |
            ((pl.col("from_account") == "804D7E820") | (pl.col("to_account") == "804D7E820")) |
            ((pl.col("from_account") == "805CA3750") | (pl.col("to_account") == "805CA3750"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80B964800") | (pl.col("to_account") == "80B964800")) |
            ((pl.col("from_account") == "806B12730") | (pl.col("to_account") == "806B12730")) |
            ((pl.col("from_account") == "8122474B0") | (pl.col("to_account") == "8122474B0")) |
            ((pl.col("from_account") == "80F034CC0") | (pl.col("to_account") == "80F034CC0")) |
            ((pl.col("from_account") == "80E5C0180") | (pl.col("to_account") == "80E5C0180")) |
            ((pl.col("from_account") == "811B16940") | (pl.col("to_account") == "811B16940")) |
            ((pl.col("from_account") == "811F76830") | (pl.col("to_account") == "811F76830")) |
            ((pl.col("from_account") == "811243150") | (pl.col("to_account") == "811243150")) |
            ((pl.col("from_account") == "802AB9080") | (pl.col("to_account") == "802AB9080")) |
            ((pl.col("from_account") == "806B5EBC0") | (pl.col("to_account") == "806B5EBC0")) |
            ((pl.col("from_account") == "80E736F40") | (pl.col("to_account") == "80E736F40"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "806A570E0") | (pl.col("to_account") == "806A570E0")) |
            ((pl.col("from_account") == "8114B6040") | (pl.col("to_account") == "8114B6040")) |
            ((pl.col("from_account") == "80D286160") | (pl.col("to_account") == "80D286160")) |
            ((pl.col("from_account") == "8093F1270") | (pl.col("to_account") == "8093F1270")) |
            ((pl.col("from_account") == "8088A4AE0") | (pl.col("to_account") == "8088A4AE0")) |
            ((pl.col("from_account") == "80DE5AFC0") | (pl.col("to_account") == "80DE5AFC0")) |
            ((pl.col("from_account") == "80E47F580") | (pl.col("to_account") == "80E47F580")) |
            ((pl.col("from_account") == "80854F3A0") | (pl.col("to_account") == "80854F3A0")) |
            ((pl.col("from_account") == "809E8F160") | (pl.col("to_account") == "809E8F160")) |
            ((pl.col("from_account") == "8069EB270") | (pl.col("to_account") == "8069EB270")) |
            ((pl.col("from_account") == "8078AF360") | (pl.col("to_account") == "8078AF360"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80113D5D0") | (pl.col("to_account") == "80113D5D0")) |
            ((pl.col("from_account") == "80BDDEE60") | (pl.col("to_account") == "80BDDEE60"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80DFAB280") | (pl.col("to_account") == "80DFAB280")) |
            ((pl.col("from_account") == "80B8C9580") | (pl.col("to_account") == "80B8C9580")) |
            ((pl.col("from_account") == "8014C0730") | (pl.col("to_account") == "8014C0730")) |
            ((pl.col("from_account") == "801DAF060") | (pl.col("to_account") == "801DAF060"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "800109820") | (pl.col("to_account") == "800109820")) |
            ((pl.col("from_account") == "8001AE260") | (pl.col("to_account") == "8001AE260"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "800EC1750") | (pl.col("to_account") == "800EC1750")) |
            ((pl.col("from_account") == "8015A6530") | (pl.col("to_account") == "8015A6530")) |
            ((pl.col("from_account") == "8011150C0") | (pl.col("to_account") == "8011150C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8062E09A0") | (pl.col("to_account") == "8062E09A0")) |
            ((pl.col("from_account") == "80EEAF1E0") | (pl.col("to_account") == "80EEAF1E0")) |
            ((pl.col("from_account") == "804EFC300") | (pl.col("to_account") == "804EFC300"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "806D31C80") | (pl.col("to_account") == "806D31C80")) |
            ((pl.col("from_account") == "80D0D5F80") | (pl.col("to_account") == "80D0D5F80")) |
            ((pl.col("from_account") == "80EB13650") | (pl.col("to_account") == "80EB13650")) |
            ((pl.col("from_account") == "80E0555C0") | (pl.col("to_account") == "80E0555C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80EE582B0") | (pl.col("to_account") == "80EE582B0")) |
            ((pl.col("from_account") == "80C2E7860") | (pl.col("to_account") == "80C2E7860")) |
            ((pl.col("from_account") == "800F5BCB0") | (pl.col("to_account") == "800F5BCB0")) |
            ((pl.col("from_account") == "8026F0EF0") | (pl.col("to_account") == "8026F0EF0")) |
            ((pl.col("from_account") == "808718090") | (pl.col("to_account") == "808718090")) |
            ((pl.col("from_account") == "8033ACE30") | (pl.col("to_account") == "8033ACE30")) |
            ((pl.col("from_account") == "80543A870") | (pl.col("to_account") == "80543A870")) |
            ((pl.col("from_account") == "8064773A0") | (pl.col("to_account") == "8064773A0")) |
            ((pl.col("from_account") == "80C90D1D0") | (pl.col("to_account") == "80C90D1D0")) |
            ((pl.col("from_account") == "80BE84A00") | (pl.col("to_account") == "80BE84A00"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80032F6C0") | (pl.col("to_account") == "80032F6C0")) |
            ((pl.col("from_account") == "800AEDA60") | (pl.col("to_account") == "800AEDA60")) |
            ((pl.col("from_account") == "800478690") | (pl.col("to_account") == "800478690")) |
            ((pl.col("from_account") == "80072E610") | (pl.col("to_account") == "80072E610")) |
            ((pl.col("from_account") == "8003EBFF0") | (pl.col("to_account") == "8003EBFF0")) |
            ((pl.col("from_account") == "800063D30") | (pl.col("to_account") == "800063D30")) |
            ((pl.col("from_account") == "80063B6D0") | (pl.col("to_account") == "80063B6D0")) |
            ((pl.col("from_account") == "80087A9A0") | (pl.col("to_account") == "80087A9A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "808FE2E00") | (pl.col("to_account") == "808FE2E00")) |
            ((pl.col("from_account") == "811F4AF40") | (pl.col("to_account") == "811F4AF40")) |
            ((pl.col("from_account") == "80C813A70") | (pl.col("to_account") == "80C813A70")) |
            ((pl.col("from_account") == "80005F430") | (pl.col("to_account") == "80005F430")) |
            ((pl.col("from_account") == "80EDF8C80") | (pl.col("to_account") == "80EDF8C80")) |
            ((pl.col("from_account") == "801771410") | (pl.col("to_account") == "801771410")) |
            ((pl.col("from_account") == "80D59FF50") | (pl.col("to_account") == "80D59FF50")) |
            ((pl.col("from_account") == "80DCF9990") | (pl.col("to_account") == "80DCF9990")) |
            ((pl.col("from_account") == "8005F0660") | (pl.col("to_account") == "8005F0660")) |
            ((pl.col("from_account") == "80F95BC50") | (pl.col("to_account") == "80F95BC50")) |
            ((pl.col("from_account") == "811B86440") | (pl.col("to_account") == "811B86440")) |
            ((pl.col("from_account") == "803E47E50") | (pl.col("to_account") == "803E47E50"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80846C890") | (pl.col("to_account") == "80846C890")) |
            ((pl.col("from_account") == "8017C4780") | (pl.col("to_account") == "8017C4780")) |
            ((pl.col("from_account") == "80BEC8340") | (pl.col("to_account") == "80BEC8340")) |
            ((pl.col("from_account") == "805AD2D20") | (pl.col("to_account") == "805AD2D20")) |
            ((pl.col("from_account") == "8027C1CE0") | (pl.col("to_account") == "8027C1CE0")) |
            ((pl.col("from_account") == "8046CBEE0") | (pl.col("to_account") == "8046CBEE0")) |
            ((pl.col("from_account") == "80C11E710") | (pl.col("to_account") == "80C11E710"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "807CF4100") | (pl.col("to_account") == "807CF4100")) |
            ((pl.col("from_account") == "80BDA4A90") | (pl.col("to_account") == "80BDA4A90")) |
            ((pl.col("from_account") == "80DDC3890") | (pl.col("to_account") == "80DDC3890")) |
            ((pl.col("from_account") == "801112050") | (pl.col("to_account") == "801112050"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))
    
    .when(
        (
            ((pl.col("from_account") == "80C3B54A0") | (pl.col("to_account") == "80C3B54A0")) |
            ((pl.col("from_account") == "80FBDD530") | (pl.col("to_account") == "80FBDD530")) |
            ((pl.col("from_account") == "80E57ABE0") | (pl.col("to_account") == "80E57ABE0")) |
            ((pl.col("from_account") == "808FC9C70") | (pl.col("to_account") == "808FC9C70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8040A5960") | (pl.col("to_account") == "8040A5960")) |
            ((pl.col("from_account") == "8022CFEB0") | (pl.col("to_account") == "8022CFEB0")) |
            ((pl.col("from_account") == "808582E80") | (pl.col("to_account") == "808582E80")) |
            ((pl.col("from_account") == "807CD84A0") | (pl.col("to_account") == "807CD84A0")) |
            ((pl.col("from_account") == "80C707860") | (pl.col("to_account") == "80C707860")) |
            ((pl.col("from_account") == "80EEC7720") | (pl.col("to_account") == "80EEC7720")) |
            ((pl.col("from_account") == "8060EC5E0") | (pl.col("to_account") == "8060EC5E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "81016E050") | (pl.col("to_account") == "81016E050")) |
            ((pl.col("from_account") == "80C1EB8B0") | (pl.col("to_account") == "80C1EB8B0")) |
            ((pl.col("from_account") == "8045732A0") | (pl.col("to_account") == "8045732A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "806CBBE20") | (pl.col("to_account") == "806CBBE20")) |
            ((pl.col("from_account") == "80171C720") | (pl.col("to_account") == "80171C720")) |
            ((pl.col("from_account") == "803118000") | (pl.col("to_account") == "803118000")) |
            ((pl.col("from_account") == "806E8ADD0") | (pl.col("to_account") == "806E8ADD0")) |
            ((pl.col("from_account") == "8073CD950") | (pl.col("to_account") == "8073CD950"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8049DD1C0") | (pl.col("to_account") == "8049DD1C0")) |
            ((pl.col("from_account") == "80BB54BC0") | (pl.col("to_account") == "80BB54BC0")) |
            ((pl.col("from_account") == "801F694E0") | (pl.col("to_account") == "801F694E0")) |
            ((pl.col("from_account") == "8004257C0") | (pl.col("to_account") == "8004257C0")) |
            ((pl.col("from_account") == "8056BC280") | (pl.col("to_account") == "8056BC280"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "801434090") | (pl.col("to_account") == "801434090")) |
            ((pl.col("from_account") == "800093C80") | (pl.col("to_account") == "800093C80")) |
            ((pl.col("from_account") == "808406960") | (pl.col("to_account") == "808406960")) |
            ((pl.col("from_account") == "80A3DE9A0") | (pl.col("to_account") == "80A3DE9A0")) |
            ((pl.col("from_account") == "80D41E7A0") | (pl.col("to_account") == "80D41E7A0")) |
            ((pl.col("from_account") == "811AF2F80") | (pl.col("to_account") == "811AF2F80")) |
            ((pl.col("from_account") == "800728800") | (pl.col("to_account") == "800728800")) |
            ((pl.col("from_account") == "8083A8800") | (pl.col("to_account") == "8083A8800"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "805A06820") | (pl.col("to_account") == "805A06820")) |
            ((pl.col("from_account") == "80307A9E0") | (pl.col("to_account") == "80307A9E0")) |
            ((pl.col("from_account") == "807214430") | (pl.col("to_account") == "807214430")) |
            ((pl.col("from_account") == "80567CFE0") | (pl.col("to_account") == "80567CFE0")) |
            ((pl.col("from_account") == "804E71900") | (pl.col("to_account") == "804E71900")) |
            ((pl.col("from_account") == "800D7F3B0") | (pl.col("to_account") == "800D7F3B0")) |
            ((pl.col("from_account") == "8042E41B0") | (pl.col("to_account") == "8042E41B0")) |
            ((pl.col("from_account") == "808112D30") | (pl.col("to_account") == "808112D30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "811EDAA30") | (pl.col("to_account") == "811EDAA30")) |
            ((pl.col("from_account") == "81235E8B0") | (pl.col("to_account") == "81235E8B0")) |
            ((pl.col("from_account") == "811A67510") | (pl.col("to_account") == "811A67510")) |
            ((pl.col("from_account") == "812D1B280") | (pl.col("to_account") == "812D1B280")) |
            ((pl.col("from_account") == "811FCA7B0") | (pl.col("to_account") == "811FCA7B0")) |
            ((pl.col("from_account") == "811EDA940") | (pl.col("to_account") == "811EDA940")) |
            ((pl.col("from_account") == "811E3C9F0") | (pl.col("to_account") == "811E3C9F0")) |
            ((pl.col("from_account") == "81235EC40") | (pl.col("to_account") == "81235EC40")) |
            ((pl.col("from_account") == "812D1A410") | (pl.col("to_account") == "812D1A410")) |
            ((pl.col("from_account") == "811ED7DF0") | (pl.col("to_account") == "811ED7DF0")) |
            ((pl.col("from_account") == "81235EAA0") | (pl.col("to_account") == "81235EAA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80016A830") | (pl.col("to_account") == "80016A830")) |
            ((pl.col("from_account") == "80023E0E0") | (pl.col("to_account") == "80023E0E0")) |
            ((pl.col("from_account") == "8000EFAF0") | (pl.col("to_account") == "8000EFAF0")) |
            ((pl.col("from_account") == "80022DF30") | (pl.col("to_account") == "80022DF30")) |
            ((pl.col("from_account") == "80016A6A0") | (pl.col("to_account") == "80016A6A0")) |
            ((pl.col("from_account") == "8002BCFF0") | (pl.col("to_account") == "8002BCFF0")) |
            ((pl.col("from_account") == "800060E60") | (pl.col("to_account") == "800060E60")) |
            ((pl.col("from_account") == "8000FE1F0") | (pl.col("to_account") == "8000FE1F0")) |
            ((pl.col("from_account") == "800063D30") | (pl.col("to_account") == "800063D30")) |
            ((pl.col("from_account") == "80010D740") | (pl.col("to_account") == "80010D740"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "811D80C30") | (pl.col("to_account") == "811D80C30")) |
            ((pl.col("from_account") == "811B9B110") | (pl.col("to_account") == "811B9B110")) |
            ((pl.col("from_account") == "811B6E170") | (pl.col("to_account") == "811B6E170")) |
            ((pl.col("from_account") == "812D06150") | (pl.col("to_account") == "812D06150")) |
            ((pl.col("from_account") == "8119F8CC0") | (pl.col("to_account") == "8119F8CC0")) |
            ((pl.col("from_account") == "80B0C3F40") | (pl.col("to_account") == "80B0C3F40")) |
            ((pl.col("from_account") == "811DCA9B0") | (pl.col("to_account") == "811DCA9B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8078DC6E0") | (pl.col("to_account") == "8078DC6E0")) |
            ((pl.col("from_account") == "8041EDC70") | (pl.col("to_account") == "8041EDC70")) |
            ((pl.col("from_account") == "80692A790") | (pl.col("to_account") == "80692A790")) |
            ((pl.col("from_account") == "805B9B260") | (pl.col("to_account") == "805B9B260")) |
            ((pl.col("from_account") == "8005A25A0") | (pl.col("to_account") == "8005A25A0")) |
            ((pl.col("from_account") == "8043410B0") | (pl.col("to_account") == "8043410B0")) |
            ((pl.col("from_account") == "807B6EA00") | (pl.col("to_account") == "807B6EA00")) |
            ((pl.col("from_account") == "80720B3B0") | (pl.col("to_account") == "80720B3B0")) |
            ((pl.col("from_account") == "8032FADC0") | (pl.col("to_account") == "8032FADC0")) |
            ((pl.col("from_account") == "801A29950") | (pl.col("to_account") == "801A29950"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "807982750") | (pl.col("to_account") == "807982750")) |
            ((pl.col("from_account") == "807341220") | (pl.col("to_account") == "807341220"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8002E86B0") | (pl.col("to_account") == "8002E86B0")) |
            ((pl.col("from_account") == "8010D33A0") | (pl.col("to_account") == "8010D33A0")) |
            ((pl.col("from_account") == "806194950") | (pl.col("to_account") == "806194950")) |
            ((pl.col("from_account") == "80E93E900") | (pl.col("to_account") == "80E93E900"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8019225A0") | (pl.col("to_account") == "8019225A0")) |
            ((pl.col("from_account") == "801774BC0") | (pl.col("to_account") == "801774BC0")) |
            ((pl.col("from_account") == "800A624A0") | (pl.col("to_account") == "800A624A0")) |
            ((pl.col("from_account") == "800DF7070") | (pl.col("to_account") == "800DF7070")) |
            ((pl.col("from_account") == "8019C00E0") | (pl.col("to_account") == "8019C00E0")) |
            ((pl.col("from_account") == "8014063B0") | (pl.col("to_account") == "8014063B0")) |
            ((pl.col("from_account") == "800FF9AA0") | (pl.col("to_account") == "800FF9AA0")) |
            ((pl.col("from_account") == "8019E4030") | (pl.col("to_account") == "8019E4030"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "8083C1550") | (pl.col("to_account") == "8083C1550")) |
            ((pl.col("from_account") == "80426FC30") | (pl.col("to_account") == "80426FC30")) |
            ((pl.col("from_account") == "8025EF980") | (pl.col("to_account") == "8025EF980")) |
            ((pl.col("from_account") == "802126270") | (pl.col("to_account") == "802126270")) |
            ((pl.col("from_account") == "804EE25D0") | (pl.col("to_account") == "804EE25D0")) |
            ((pl.col("from_account") == "80604C300") | (pl.col("to_account") == "80604C300")) |
            ((pl.col("from_account") == "805C42580") | (pl.col("to_account") == "805C42580")) |
            ((pl.col("from_account") == "8010F8CE0") | (pl.col("to_account") == "8010F8CE0")) |
            ((pl.col("from_account") == "8029A03B0") | (pl.col("to_account") == "8029A03B0")) |
            ((pl.col("from_account") == "805DFF260") | (pl.col("to_account") == "805DFF260")) |
            ((pl.col("from_account") == "803CF7A80") | (pl.col("to_account") == "803CF7A80"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))

    .when(
        (
            ((pl.col("from_account") == "80010ECB0") | (pl.col("to_account") == "80010ECB0")) |
            ((pl.col("from_account") == "800248110") | (pl.col("to_account") == "800248110")) |
            ((pl.col("from_account") == "800052EF0") | (pl.col("to_account") == "800052EF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(4))
      
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 4)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as cycle: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as cycle: 424
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 1467      ┆ 8013C4030    ┆ 20      ┆ 80BC62F10  ┆ 1             ┆ 4       │
# │ 20        ┆ 80BC62F10    ┆ 240229  ┆ 80F025640  ┆ 1             ┆ 4       │
# │ 240229    ┆ 80F025640    ┆ 217     ┆ 80FD27570  ┆ 1             ┆ 4       │
# │ 217       ┆ 80FD27570    ┆ 24856   ┆ 8090E8EB0  ┆ 1             ┆ 4       │
# │ 24856     ┆ 8090E8EB0    ┆ 71      ┆ 804ABCE90  ┆ 1             ┆ 4       │
# │ 71        ┆ 804ABCE90    ┆ 213737  ┆ 805494C30  ┆ 1             ┆ 4       │
# ...

# %% [markdown]
# ### Stack

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_account") == "8000DD890") | (pl.col("to_account") == "8000DD890")) |
            ((pl.col("from_account") == "80F52D550") | (pl.col("to_account") == "80F52D550")) |
            ((pl.col("from_account") == "80BEA98A0") | (pl.col("to_account") == "80BEA98A0")) |
            ((pl.col("from_account") == "8038D3520") | (pl.col("to_account") == "8038D3520")) |
            ((pl.col("from_account") == "801C0F2B0") | (pl.col("to_account") == "801C0F2B0")) |
            ((pl.col("from_account") == "80C1B9E20") | (pl.col("to_account") == "80C1B9E20")) |
            ((pl.col("from_account") == "80F6B88B0") | (pl.col("to_account") == "80F6B88B0")) |
            ((pl.col("from_account") == "8064545E0") | (pl.col("to_account") == "8064545E0")) |
            ((pl.col("from_account") == "80662A070") | (pl.col("to_account") == "80662A070")) |
            ((pl.col("from_account") == "8014BDC90") | (pl.col("to_account") == "8014BDC90")) |
            ((pl.col("from_account") == "80537F610") | (pl.col("to_account") == "80537F610")) |
            ((pl.col("from_account") == "806C8F2A0") | (pl.col("to_account") == "806C8F2A0")) |
            ((pl.col("from_account") == "80195DE20") | (pl.col("to_account") == "80195DE20")) |
            ((pl.col("from_account") == "801E2BC20") | (pl.col("to_account") == "801E2BC20")) |
            ((pl.col("from_account") == "807E97240") | (pl.col("to_account") == "807E97240")) |
            ((pl.col("from_account") == "8009CF210") | (pl.col("to_account") == "8009CF210")) |
            ((pl.col("from_account") == "8011AB110") | (pl.col("to_account") == "8011AB110")) |
            ((pl.col("from_account") == "806C7CF80") | (pl.col("to_account") == "806C7CF80")) |
            ((pl.col("from_account") == "803FF9220") | (pl.col("to_account") == "803FF9220")) |
            ((pl.col("from_account") == "81114D580") | (pl.col("to_account") == "81114D580")) |
            ((pl.col("from_account") == "809BD8BC0") | (pl.col("to_account") == "809BD8BC0")) |
            ((pl.col("from_account") == "80B3E96E0") | (pl.col("to_account") == "80B3E96E0")) |
            ((pl.col("from_account") == "801F8CCB0") | (pl.col("to_account") == "801F8CCB0")) |
            ((pl.col("from_account") == "801C92FF0") | (pl.col("to_account") == "801C92FF0")) |
            ((pl.col("from_account") == "807A61380") | (pl.col("to_account") == "807A61380")) |
            ((pl.col("from_account") == "802D53D80") | (pl.col("to_account") == "802D53D80")) |
            ((pl.col("from_account") == "80EE2B9B0") | (pl.col("to_account") == "80EE2B9B0")) |
            ((pl.col("from_account") == "80B7347A0") | (pl.col("to_account") == "80B7347A0")) |
            ((pl.col("from_account") == "802D878C0") | (pl.col("to_account") == "802D878C0")) |
            ((pl.col("from_account") == "8063F5290") | (pl.col("to_account") == "8063F5290")) |
            ((pl.col("from_account") == "80A1C7710") | (pl.col("to_account") == "80A1C7710")) |
            ((pl.col("from_account") == "80A09CF50") | (pl.col("to_account") == "80A09CF50")) |
            ((pl.col("from_account") == "8067AD0A0") | (pl.col("to_account") == "8067AD0A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))  # STACK

    .when(
        (
            ((pl.col("from_account") == "80241BD20") | (pl.col("to_account") == "80241BD20")) |
            ((pl.col("from_account") == "800E44770") | (pl.col("to_account") == "800E44770")) |
            ((pl.col("from_account") == "8019B81D0") | (pl.col("to_account") == "8019B81D0")) |
            ((pl.col("from_account") == "800ACC410") | (pl.col("to_account") == "800ACC410")) |
            ((pl.col("from_account") == "8004FBC70") | (pl.col("to_account") == "8004FBC70")) |
            ((pl.col("from_account") == "8014322B0") | (pl.col("to_account") == "8014322B0")) |
            ((pl.col("from_account") == "8011EF080") | (pl.col("to_account") == "8011EF080")) |
            ((pl.col("from_account") == "8010B21A0") | (pl.col("to_account") == "8010B21A0")) |
            ((pl.col("from_account") == "80016E400") | (pl.col("to_account") == "80016E400")) |
            ((pl.col("from_account") == "8019E64E0") | (pl.col("to_account") == "8019E64E0")) |
            ((pl.col("from_account") == "80118E680") | (pl.col("to_account") == "80118E680")) |
            ((pl.col("from_account") == "800BA92A0") | (pl.col("to_account") == "800BA92A0")) |
            ((pl.col("from_account") == "800981370") | (pl.col("to_account") == "800981370")) |
            ((pl.col("from_account") == "8002B9DE0") | (pl.col("to_account") == "8002B9DE0")) |
            ((pl.col("from_account") == "800160AF0") | (pl.col("to_account") == "800160AF0")) |
            ((pl.col("from_account") == "8011F0870") | (pl.col("to_account") == "8011F0870")) |
            ((pl.col("from_account") == "8016FDD30") | (pl.col("to_account") == "8016FDD30")) |
            ((pl.col("from_account") == "8001AEBF0") | (pl.col("to_account") == "8001AEBF0")) |
            ((pl.col("from_account") == "801E72C20") | (pl.col("to_account") == "801E72C20")) |
            ((pl.col("from_account") == "801D887E0") | (pl.col("to_account") == "801D887E0")) |
            ((pl.col("from_account") == "80069E9E0") | (pl.col("to_account") == "80069E9E0")) |
            ((pl.col("from_account") == "80030CC80") | (pl.col("to_account") == "80030CC80")) |
            ((pl.col("from_account") == "800E79AE0") | (pl.col("to_account") == "800E79AE0")) |
            ((pl.col("from_account") == "800164250") | (pl.col("to_account") == "800164250")) |
            ((pl.col("from_account") == "8013D2F20") | (pl.col("to_account") == "8013D2F20")) |
            ((pl.col("from_account") == "801908010") | (pl.col("to_account") == "801908010")) |
            ((pl.col("from_account") == "801EFC5C0") | (pl.col("to_account") == "801EFC5C0")) |
            ((pl.col("from_account") == "801010DF0") | (pl.col("to_account") == "801010DF0")) |
            ((pl.col("from_account") == "8015CC830") | (pl.col("to_account") == "8015CC830")) |
            ((pl.col("from_account") == "8010BC410") | (pl.col("to_account") == "8010BC410"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "800637C70") | (pl.col("to_account") == "800637C70")) |
            ((pl.col("from_account") == "800DF3270") | (pl.col("to_account") == "800DF3270")) |
            ((pl.col("from_account") == "801260570") | (pl.col("to_account") == "801260570")) |
            ((pl.col("from_account") == "80DB0B9D0") | (pl.col("to_account") == "80DB0B9D0")) |
            ((pl.col("from_account") == "8078A4130") | (pl.col("to_account") == "8078A4130")) |
            ((pl.col("from_account") == "8044969E0") | (pl.col("to_account") == "8044969E0")) |
            ((pl.col("from_account") == "80C381B70") | (pl.col("to_account") == "80C381B70")) |
            ((pl.col("from_account") == "80CC4B000") | (pl.col("to_account") == "80CC4B000")) |
            ((pl.col("from_account") == "8020DDAF0") | (pl.col("to_account") == "8020DDAF0")) |
            ((pl.col("from_account") == "80820F1A0") | (pl.col("to_account") == "80820F1A0")) |
            ((pl.col("from_account") == "800BA6480") | (pl.col("to_account") == "800BA6480")) |
            ((pl.col("from_account") == "80DB57310") | (pl.col("to_account") == "80DB57310")) |
            ((pl.col("from_account") == "80832A480") | (pl.col("to_account") == "80832A480")) |
            ((pl.col("from_account") == "805D535A0") | (pl.col("to_account") == "805D535A0")) |
            ((pl.col("from_account") == "802D21780") | (pl.col("to_account") == "802D21780")) |
            ((pl.col("from_account") == "8085DD9A0") | (pl.col("to_account") == "8085DD9A0")) |
            ((pl.col("from_account") == "80693AB90") | (pl.col("to_account") == "80693AB90")) |
            ((pl.col("from_account") == "800049680") | (pl.col("to_account") == "800049680")) |
            ((pl.col("from_account") == "806C8A860") | (pl.col("to_account") == "806C8A860")) |
            ((pl.col("from_account") == "803C0D4D0") | (pl.col("to_account") == "803C0D4D0")) |
            ((pl.col("from_account") == "80E5CF6B0") | (pl.col("to_account") == "80E5CF6B0")) |
            ((pl.col("from_account") == "805EB6DE0") | (pl.col("to_account") == "805EB6DE0")) |
            ((pl.col("from_account") == "8038F4190") | (pl.col("to_account") == "8038F4190")) |
            ((pl.col("from_account") == "805331420") | (pl.col("to_account") == "805331420")) |
            ((pl.col("from_account") == "80C379450") | (pl.col("to_account") == "80C379450")) |
            ((pl.col("from_account") == "80A7B9290") | (pl.col("to_account") == "80A7B9290")) |
            ((pl.col("from_account") == "807962B90") | (pl.col("to_account") == "807962B90")) |
            ((pl.col("from_account") == "80AD2BB10") | (pl.col("to_account") == "80AD2BB10")) |
            ((pl.col("from_account") == "80A43F620") | (pl.col("to_account") == "80A43F620")) |
            ((pl.col("from_account") == "8099A7B50") | (pl.col("to_account") == "8099A7B50")) |
            ((pl.col("from_account") == "80BBEDC60") | (pl.col("to_account") == "80BBEDC60")) |
            ((pl.col("from_account") == "80484E640") | (pl.col("to_account") == "80484E640")) |
            ((pl.col("from_account") == "80DF46F20") | (pl.col("to_account") == "80DF46F20"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80709E010") | (pl.col("to_account") == "80709E010")) |
            ((pl.col("from_account") == "806B1F6F0") | (pl.col("to_account") == "806B1F6F0")) |
            ((pl.col("from_account") == "8090E9B70") | (pl.col("to_account") == "8090E9B70")) |
            ((pl.col("from_account") == "803FEFF90") | (pl.col("to_account") == "803FEFF90")) |
            ((pl.col("from_account") == "802A4BBD0") | (pl.col("to_account") == "802A4BBD0")) |
            ((pl.col("from_account") == "803CB3490") | (pl.col("to_account") == "803CB3490")) |
            ((pl.col("from_account") == "80C84A040") | (pl.col("to_account") == "80C84A040")) |
            ((pl.col("from_account") == "80557A9D0") | (pl.col("to_account") == "80557A9D0")) |
            ((pl.col("from_account") == "811A12A90") | (pl.col("to_account") == "811A12A90")) |
            ((pl.col("from_account") == "801FE25A0") | (pl.col("to_account") == "801FE25A0")) |
            ((pl.col("from_account") == "806B66F00") | (pl.col("to_account") == "806B66F00")) |
            ((pl.col("from_account") == "80F2BFA30") | (pl.col("to_account") == "80F2BFA30")) |
            ((pl.col("from_account") == "8078DFC60") | (pl.col("to_account") == "8078DFC60")) |
            ((pl.col("from_account") == "8086E0A20") | (pl.col("to_account") == "8086E0A20")) |
            ((pl.col("from_account") == "809292360") | (pl.col("to_account") == "809292360")) |
            ((pl.col("from_account") == "811EA7B80") | (pl.col("to_account") == "811EA7B80")) |
            ((pl.col("from_account") == "80331DE30") | (pl.col("to_account") == "80331DE30")) |
            ((pl.col("from_account") == "80A671210") | (pl.col("to_account") == "80A671210"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8021CF080") | (pl.col("to_account") == "8021CF080")) |
            ((pl.col("from_account") == "8014E85C0") | (pl.col("to_account") == "8014E85C0")) |
            ((pl.col("from_account") == "8007C82A0") | (pl.col("to_account") == "8007C82A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80292C690") | (pl.col("to_account") == "80292C690")) |
            ((pl.col("from_account") == "80AD1F390") | (pl.col("to_account") == "80AD1F390")) |
            ((pl.col("from_account") == "80E4FDA80") | (pl.col("to_account") == "80E4FDA80"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "805C8AC70") | (pl.col("to_account") == "805C8AC70")) |
            ((pl.col("from_account") == "80FD88340") | (pl.col("to_account") == "80FD88340")) |
            ((pl.col("from_account") == "8022C5CF0") | (pl.col("to_account") == "8022C5CF0")) |
            ((pl.col("from_account") == "80C803F50") | (pl.col("to_account") == "80C803F50")) |
            ((pl.col("from_account") == "80D604BC0") | (pl.col("to_account") == "80D604BC0")) |
            ((pl.col("from_account") == "80009F920") | (pl.col("to_account") == "80009F920")) |
            ((pl.col("from_account") == "8071AF070") | (pl.col("to_account") == "8071AF070")) |
            ((pl.col("from_account") == "80D52F130") | (pl.col("to_account") == "80D52F130")) |
            ((pl.col("from_account") == "80FEDCCD0") | (pl.col("to_account") == "80FEDCCD0")) |
            ((pl.col("from_account") == "8068E42C0") | (pl.col("to_account") == "8068E42C0")) |
            ((pl.col("from_account") == "80A885E10") | (pl.col("to_account") == "80A885E10")) |
            ((pl.col("from_account") == "806D922C0") | (pl.col("to_account") == "806D922C0")) |
            ((pl.col("from_account") == "80CA50CE0") | (pl.col("to_account") == "80CA50CE0")) |
            ((pl.col("from_account") == "805E124A0") | (pl.col("to_account") == "805E124A0")) |
            ((pl.col("from_account") == "8058F18D0") | (pl.col("to_account") == "8058F18D0")) |
            ((pl.col("from_account") == "811D3FB50") | (pl.col("to_account") == "811D3FB50")) |
            ((pl.col("from_account") == "802E7CA30") | (pl.col("to_account") == "802E7CA30")) |
            ((pl.col("from_account") == "804675CF0") | (pl.col("to_account") == "804675CF0")) |
            ((pl.col("from_account") == "80CC9C960") | (pl.col("to_account") == "80CC9C960")) |
            ((pl.col("from_account") == "80DEB15D0") | (pl.col("to_account") == "80DEB15D0")) |
            ((pl.col("from_account") == "80C6E9A60") | (pl.col("to_account") == "80C6E9A60")) |
            ((pl.col("from_account") == "80E435B80") | (pl.col("to_account") == "80E435B80")) |
            ((pl.col("from_account") == "80CEC9B70") | (pl.col("to_account") == "80CEC9B70")) |
            ((pl.col("from_account") == "80CFC2BB0") | (pl.col("to_account") == "80CFC2BB0")) |
            ((pl.col("from_account") == "80B2250B0") | (pl.col("to_account") == "80B2250B0")) |
            ((pl.col("from_account") == "810499990") | (pl.col("to_account") == "810499990")) |
            ((pl.col("from_account") == "806B445D0") | (pl.col("to_account") == "806B445D0")) |
            ((pl.col("from_account") == "80EADAC60") | (pl.col("to_account") == "80EADAC60")) |
            ((pl.col("from_account") == "80EE5F840") | (pl.col("to_account") == "80EE5F840")) |
            ((pl.col("from_account") == "807919990") | (pl.col("to_account") == "807919990")) |
            ((pl.col("from_account") == "809CE12E0") | (pl.col("to_account") == "809CE12E0")) |
            ((pl.col("from_account") == "8061A6010") | (pl.col("to_account") == "8061A6010")) |
            ((pl.col("from_account") == "806C62690") | (pl.col("to_account") == "806C62690")) |
            ((pl.col("from_account") == "800E3F5A0") | (pl.col("to_account") == "800E3F5A0")) |
            ((pl.col("from_account") == "8065C8A80") | (pl.col("to_account") == "8065C8A80")) |
            ((pl.col("from_account") == "80931DDE0") | (pl.col("to_account") == "80931DDE0")) |
            ((pl.col("from_account") == "80C1ED8D0") | (pl.col("to_account") == "80C1ED8D0")) |
            ((pl.col("from_account") == "8077C0760") | (pl.col("to_account") == "8077C0760")) |
            ((pl.col("from_account") == "80B19AF00") | (pl.col("to_account") == "80B19AF00")) |
            ((pl.col("from_account") == "8089009F0") | (pl.col("to_account") == "8089009F0")) |
            ((pl.col("from_account") == "80373C140") | (pl.col("to_account") == "80373C140")) |
            ((pl.col("from_account") == "804A30000") | (pl.col("to_account") == "804A30000")) |
            ((pl.col("from_account") == "811A0FA00") | (pl.col("to_account") == "811A0FA00")) |
            ((pl.col("from_account") == "80B82EF40") | (pl.col("to_account") == "80B82EF40")) |
            ((pl.col("from_account") == "8028B70E0") | (pl.col("to_account") == "8028B70E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))


    .when(
        (
            ((pl.col("from_account") == "801AA4400") | (pl.col("to_account") == "801AA4400")) |
            ((pl.col("from_account") == "80963CB30") | (pl.col("to_account") == "80963CB30")) |
            ((pl.col("from_account") == "805811F40") | (pl.col("to_account") == "805811F40")) |
            ((pl.col("from_account") == "80EBC6370") | (pl.col("to_account") == "80EBC6370")) |
            ((pl.col("from_account") == "80D151C70") | (pl.col("to_account") == "80D151C70")) |
            ((pl.col("from_account") == "80A6536E0") | (pl.col("to_account") == "80A6536E0")) |
            ((pl.col("from_account") == "80AB2B9B0") | (pl.col("to_account") == "80AB2B9B0")) |
            ((pl.col("from_account") == "8043A9F30") | (pl.col("to_account") == "8043A9F30")) |
            ((pl.col("from_account") == "80B115430") | (pl.col("to_account") == "80B115430")) |
            ((pl.col("from_account") == "80D030A40") | (pl.col("to_account") == "80D030A40")) |
            ((pl.col("from_account") == "80F203B70") | (pl.col("to_account") == "80F203B70")) |
            ((pl.col("from_account") == "805438E60") | (pl.col("to_account") == "805438E60"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "800D63EE0") | (pl.col("to_account") == "800D63EE0")) |
            ((pl.col("from_account") == "8070043E0") | (pl.col("to_account") == "8070043E0")) |
            ((pl.col("from_account") == "804D324A0") | (pl.col("to_account") == "804D324A0")) |
            ((pl.col("from_account") == "803ED92E0") | (pl.col("to_account") == "803ED92E0")) |
            ((pl.col("from_account") == "80721A5A0") | (pl.col("to_account") == "80721A5A0")) |
            ((pl.col("from_account") == "8039B4CB0") | (pl.col("to_account") == "8039B4CB0")) |
            ((pl.col("from_account") == "8041FBAC0") | (pl.col("to_account") == "8041FBAC0")) |
            ((pl.col("from_account") == "80FEFC340") | (pl.col("to_account") == "80FEFC340")) |
            ((pl.col("from_account") == "8005DCD00") | (pl.col("to_account") == "8005DCD00")) |
            ((pl.col("from_account") == "806A7BE10") | (pl.col("to_account") == "806A7BE10")) |
            ((pl.col("from_account") == "810805FE0") | (pl.col("to_account") == "810805FE0")) |
            ((pl.col("from_account") == "80CEA8100") | (pl.col("to_account") == "80CEA8100")) |
            ((pl.col("from_account") == "80C78A190") | (pl.col("to_account") == "80C78A190")) |
            ((pl.col("from_account") == "810E92FB0") | (pl.col("to_account") == "810E92FB0")) |
            ((pl.col("from_account") == "804D12400") | (pl.col("to_account") == "804D12400")) |
            ((pl.col("from_account") == "80EFD2B30") | (pl.col("to_account") == "80EFD2B30")) |
            ((pl.col("from_account") == "80256C060") | (pl.col("to_account") == "80256C060")) |
            ((pl.col("from_account") == "80BE3A910") | (pl.col("to_account") == "80BE3A910")) |
            ((pl.col("from_account") == "8101AEF90") | (pl.col("to_account") == "8101AEF90")) |
            ((pl.col("from_account") == "80DF9EF10") | (pl.col("to_account") == "80DF9EF10")) |
            ((pl.col("from_account") == "810BEA5B0") | (pl.col("to_account") == "810BEA5B0")) |
            ((pl.col("from_account") == "8021C45F0") | (pl.col("to_account") == "8021C45F0")) |
            ((pl.col("from_account") == "8034C7AE0") | (pl.col("to_account") == "8034C7AE0")) |
            ((pl.col("from_account") == "805EC22B0") | (pl.col("to_account") == "805EC22B0")) |
            ((pl.col("from_account") == "811CD2450") | (pl.col("to_account") == "811CD2450")) |
            ((pl.col("from_account") == "808D6FCD0") | (pl.col("to_account") == "808D6FCD0")) |
            ((pl.col("from_account") == "806B31680") | (pl.col("to_account") == "806B31680")) |
            ((pl.col("from_account") == "80DCDEA20") | (pl.col("to_account") == "80DCDEA20")) |
            ((pl.col("from_account") == "808A3AF80") | (pl.col("to_account") == "808A3AF80")) |
            ((pl.col("from_account") == "808CEE0D0") | (pl.col("to_account") == "808CEE0D0")) |
            ((pl.col("from_account") == "8035CD610") | (pl.col("to_account") == "8035CD610")) |
            ((pl.col("from_account") == "8050B7870") | (pl.col("to_account") == "8050B7870")) |
            ((pl.col("from_account") == "8109C87A0") | (pl.col("to_account") == "8109C87A0")) |
            ((pl.col("from_account") == "80D76EB80") | (pl.col("to_account") == "80D76EB80")) |
            ((pl.col("from_account") == "80B68FE00") | (pl.col("to_account") == "80B68FE00")) |
            ((pl.col("from_account") == "803E8D000") | (pl.col("to_account") == "803E8D000")) |
            ((pl.col("from_account") == "803FBEE10") | (pl.col("to_account") == "803FBEE10")) |
            ((pl.col("from_account") == "808405BE0") | (pl.col("to_account") == "808405BE0")) |
            ((pl.col("from_account") == "80F3C35F0") | (pl.col("to_account") == "80F3C35F0")) |
            ((pl.col("from_account") == "8056D0240") | (pl.col("to_account") == "8056D0240")) |
            ((pl.col("from_account") == "801C04E20") | (pl.col("to_account") == "801C04E20")) |
            ((pl.col("from_account") == "80E3069E0") | (pl.col("to_account") == "80E3069E0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8000F8070") | (pl.col("to_account") == "8000F8070")) |
            ((pl.col("from_account") == "80029D5F0") | (pl.col("to_account") == "80029D5F0")) |
            ((pl.col("from_account") == "8001426D0") | (pl.col("to_account") == "8001426D0")) |
            ((pl.col("from_account") == "80023FEE0") | (pl.col("to_account") == "80023FEE0")) |
            ((pl.col("from_account") == "8001B7A10") | (pl.col("to_account") == "8001B7A10")) |
            ((pl.col("from_account") == "80029B620") | (pl.col("to_account") == "80029B620")) |
            ((pl.col("from_account") == "80027D490") | (pl.col("to_account") == "80027D490")) |
            ((pl.col("from_account") == "8002997C0") | (pl.col("to_account") == "8002997C0")) |
            ((pl.col("from_account") == "80010C100") | (pl.col("to_account") == "80010C100")) |
            ((pl.col("from_account") == "800161D40") | (pl.col("to_account") == "800161D40")) |
            ((pl.col("from_account") == "80026F8F0") | (pl.col("to_account") == "80026F8F0")) |
            ((pl.col("from_account") == "80005FD30") | (pl.col("to_account") == "80005FD30")) |
            ((pl.col("from_account") == "8000EF670") | (pl.col("to_account") == "8000EF670")) |
            ((pl.col("from_account") == "8001093C0") | (pl.col("to_account") == "8001093C0")) |
            ((pl.col("from_account") == "80010A750") | (pl.col("to_account") == "80010A750")) |
            ((pl.col("from_account") == "800102120") | (pl.col("to_account") == "800102120")) |
            ((pl.col("from_account") == "8000F49E0") | (pl.col("to_account") == "8000F49E0")) |
            ((pl.col("from_account") == "800063990") | (pl.col("to_account") == "800063990")) |
            ((pl.col("from_account") == "8000EEE80") | (pl.col("to_account") == "8000EEE80")) |
            ((pl.col("from_account") == "8000631E0") | (pl.col("to_account") == "8000631E0")) |
            ((pl.col("from_account") == "800205E90") | (pl.col("to_account") == "800205E90")) |
            ((pl.col("from_account") == "800055A70") | (pl.col("to_account") == "800055A70")) |
            ((pl.col("from_account") == "800122600") | (pl.col("to_account") == "800122600")) |
            ((pl.col("from_account") == "800177290") | (pl.col("to_account") == "800177290"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "801887E70") | (pl.col("to_account") == "801887E70")) |
            ((pl.col("from_account") == "805409060") | (pl.col("to_account") == "805409060")) |
            ((pl.col("from_account") == "803CF4370") | (pl.col("to_account") == "803CF4370")) |
            ((pl.col("from_account") == "80791F9C0") | (pl.col("to_account") == "80791F9C0")) |
            ((pl.col("from_account") == "808AE2130") | (pl.col("to_account") == "808AE2130")) |
            ((pl.col("from_account") == "80C446BA0") | (pl.col("to_account") == "80C446BA0")) |
            ((pl.col("from_account") == "805791710") | (pl.col("to_account") == "805791710")) |
            ((pl.col("from_account") == "80F7EFBE0") | (pl.col("to_account") == "80F7EFBE0")) |
            ((pl.col("from_account") == "8007A8600") | (pl.col("to_account") == "8007A8600")) |
            ((pl.col("from_account") == "804F6B6E0") | (pl.col("to_account") == "804F6B6E0")) |
            ((pl.col("from_account") == "801E30F10") | (pl.col("to_account") == "801E30F10")) |
            ((pl.col("from_account") == "801FC1E30") | (pl.col("to_account") == "801FC1E30")) |
            ((pl.col("from_account") == "80BB947A0") | (pl.col("to_account") == "80BB947A0")) |
            ((pl.col("from_account") == "8010D4FC0") | (pl.col("to_account") == "8010D4FC0")) |
            ((pl.col("from_account") == "80C981A10") | (pl.col("to_account") == "80C981A10")) |
            ((pl.col("from_account") == "80AD40250") | (pl.col("to_account") == "80AD40250")) |
            ((pl.col("from_account") == "808C30740") | (pl.col("to_account") == "808C30740")) |
            ((pl.col("from_account") == "8100920E0") | (pl.col("to_account") == "8100920E0")) |
            ((pl.col("from_account") == "80CE3BE30") | (pl.col("to_account") == "80CE3BE30")) |
            ((pl.col("from_account") == "807B41560") | (pl.col("to_account") == "807B41560")) |
            ((pl.col("from_account") == "805588D30") | (pl.col("to_account") == "805588D30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "811B6E700") | (pl.col("to_account") == "811B6E700")) |
            ((pl.col("from_account") == "809B40B80") | (pl.col("to_account") == "809B40B80")) |
            ((pl.col("from_account") == "80F349C90") | (pl.col("to_account") == "80F349C90"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "803330DF0") | (pl.col("to_account") == "803330DF0")) |
            ((pl.col("from_account") == "80DE49790") | (pl.col("to_account") == "80DE49790")) |
            ((pl.col("from_account") == "8063E9D30") | (pl.col("to_account") == "8063E9D30")) |
            ((pl.col("from_account") == "80ED2CC20") | (pl.col("to_account") == "80ED2CC20")) |
            ((pl.col("from_account") == "8034EE910") | (pl.col("to_account") == "8034EE910")) |
            ((pl.col("from_account") == "8058D9160") | (pl.col("to_account") == "8058D9160")) |
            ((pl.col("from_account") == "80853A9D0") | (pl.col("to_account") == "80853A9D0")) |
            ((pl.col("from_account") == "80468A0F0") | (pl.col("to_account") == "80468A0F0")) |
            ((pl.col("from_account") == "80E485F50") | (pl.col("to_account") == "80E485F50")) |
            ((pl.col("from_account") == "802C34490") | (pl.col("to_account") == "802C34490")) |
            ((pl.col("from_account") == "8006345A0") | (pl.col("to_account") == "8006345A0")) |
            ((pl.col("from_account") == "800FC2A60") | (pl.col("to_account") == "800FC2A60")) |
            ((pl.col("from_account") == "8062B9FD0") | (pl.col("to_account") == "8062B9FD0")) |
            ((pl.col("from_account") == "80DAD2370") | (pl.col("to_account") == "80DAD2370")) |
            ((pl.col("from_account") == "80FBBF780") | (pl.col("to_account") == "80FBBF780")) |
            ((pl.col("from_account") == "8000F00D0") | (pl.col("to_account") == "8000F00D0")) |
            ((pl.col("from_account") == "8059B6FB0") | (pl.col("to_account") == "8059B6FB0")) |
            ((pl.col("from_account") == "8007F5F30") | (pl.col("to_account") == "8007F5F30")) |
            ((pl.col("from_account") == "80FDC3670") | (pl.col("to_account") == "80FDC3670")) |
            ((pl.col("from_account") == "802077CB0") | (pl.col("to_account") == "802077CB0")) |
            ((pl.col("from_account") == "8091C8CD0") | (pl.col("to_account") == "8091C8CD0")) |
            ((pl.col("from_account") == "800FB5AB0") | (pl.col("to_account") == "800FB5AB0")) |
            ((pl.col("from_account") == "81023CDC0") | (pl.col("to_account") == "81023CDC0")) |
            ((pl.col("from_account") == "807A65360") | (pl.col("to_account") == "807A65360")) |
            ((pl.col("from_account") == "805673600") | (pl.col("to_account") == "805673600")) |
            ((pl.col("from_account") == "808697F70") | (pl.col("to_account") == "808697F70")) |
            ((pl.col("from_account") == "804D08300") | (pl.col("to_account") == "804D08300")) |
            ((pl.col("from_account") == "803C12800") | (pl.col("to_account") == "803C12800")) |
            ((pl.col("from_account") == "80A644C70") | (pl.col("to_account") == "80A644C70")) |
            ((pl.col("from_account") == "806174CC0") | (pl.col("to_account") == "806174CC0")) |
            ((pl.col("from_account") == "80C65FCB0") | (pl.col("to_account") == "80C65FCB0")) |
            ((pl.col("from_account") == "80957D980") | (pl.col("to_account") == "80957D980")) |
            ((pl.col("from_account") == "804FFC170") | (pl.col("to_account") == "804FFC170")) |
            ((pl.col("from_account") == "801783860") | (pl.col("to_account") == "801783860")) |
            ((pl.col("from_account") == "8081D8F80") | (pl.col("to_account") == "8081D8F80")) |
            ((pl.col("from_account") == "803E4FA30") | (pl.col("to_account") == "803E4FA30")) |
            ((pl.col("from_account") == "81062E050") | (pl.col("to_account") == "81062E050")) |
            ((pl.col("from_account") == "810617860") | (pl.col("to_account") == "810617860")) |
            ((pl.col("from_account") == "81225DDF0") | (pl.col("to_account") == "81225DDF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8002AEA60") | (pl.col("to_account") == "8002AEA60")) |
            ((pl.col("from_account") == "80080ABC0") | (pl.col("to_account") == "80080ABC0")) |
            ((pl.col("from_account") == "8000F1AF0") | (pl.col("to_account") == "8000F1AF0")) |
            ((pl.col("from_account") == "8000635D0") | (pl.col("to_account") == "8000635D0")) |
            ((pl.col("from_account") == "800103300") | (pl.col("to_account") == "800103300")) |
            ((pl.col("from_account") == "80027F7A0") | (pl.col("to_account") == "80027F7A0")) |
            ((pl.col("from_account") == "800240B70") | (pl.col("to_account") == "800240B70")) |
            ((pl.col("from_account") == "80005B110") | (pl.col("to_account") == "80005B110")) |
            ((pl.col("from_account") == "800205030") | (pl.col("to_account") == "800205030")) |
            ((pl.col("from_account") == "80023CE80") | (pl.col("to_account") == "80023CE80")) |
            ((pl.col("from_account") == "8001B9E90") | (pl.col("to_account") == "8001B9E90")) |
            ((pl.col("from_account") == "8001B8900") | (pl.col("to_account") == "8001B8900")) |
            ((pl.col("from_account") == "80026E2C0") | (pl.col("to_account") == "80026E2C0")) |
            ((pl.col("from_account") == "80026F7B0") | (pl.col("to_account") == "80026F7B0")) |
            ((pl.col("from_account") == "800235EC0") | (pl.col("to_account") == "800235EC0")) |
            ((pl.col("from_account") == "80011AE70") | (pl.col("to_account") == "80011AE70")) |
            ((pl.col("from_account") == "800061190") | (pl.col("to_account") == "800061190")) |
            ((pl.col("from_account") == "800068180") | (pl.col("to_account") == "800068180")) |
            ((pl.col("from_account") == "8000FF830") | (pl.col("to_account") == "8000FF830")) |
            ((pl.col("from_account") == "80022EEB0") | (pl.col("to_account") == "80022EEB0")) |
            ((pl.col("from_account") == "8001BEBD0") | (pl.col("to_account") == "8001BEBD0")) |
            ((pl.col("from_account") == "80029B9A0") | (pl.col("to_account") == "80029B9A0")) |
            ((pl.col("from_account") == "8001253F0") | (pl.col("to_account") == "8001253F0")) |
            ((pl.col("from_account") == "8000746C0") | (pl.col("to_account") == "8000746C0")) |
            ((pl.col("from_account") == "800116420") | (pl.col("to_account") == "800116420")) |
            ((pl.col("from_account") == "8001A4020") | (pl.col("to_account") == "8001A4020")) |
            ((pl.col("from_account") == "800126360") | (pl.col("to_account") == "800126360")) |
            ((pl.col("from_account") == "800278B80") | (pl.col("to_account") == "800278B80")) |
            ((pl.col("from_account") == "8001B2240") | (pl.col("to_account") == "8001B2240")) |
            ((pl.col("from_account") == "80017C540") | (pl.col("to_account") == "80017C540")) |
            ((pl.col("from_account") == "80023AB40") | (pl.col("to_account") == "80023AB40")) |
            ((pl.col("from_account") == "8001090A0") | (pl.col("to_account") == "8001090A0")) |
            ((pl.col("from_account") == "80017B3D0") | (pl.col("to_account") == "80017B3D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80C924F70") | (pl.col("to_account") == "80C924F70")) |
            ((pl.col("from_account") == "80857D940") | (pl.col("to_account") == "80857D940")) |
            ((pl.col("from_account") == "810DCEAA0") | (pl.col("to_account") == "810DCEAA0")) |
            ((pl.col("from_account") == "806685680") | (pl.col("to_account") == "806685680")) |
            ((pl.col("from_account") == "801A90E20") | (pl.col("to_account") == "801A90E20")) |
            ((pl.col("from_account") == "8030A5760") | (pl.col("to_account") == "8030A5760")) |
            ((pl.col("from_account") == "8034A7D40") | (pl.col("to_account") == "8034A7D40")) |
            ((pl.col("from_account") == "810FA0630") | (pl.col("to_account") == "810FA0630")) |
            ((pl.col("from_account") == "808476060") | (pl.col("to_account") == "808476060")) |
            ((pl.col("from_account") == "80F1C1CE0") | (pl.col("to_account") == "80F1C1CE0")) |
            ((pl.col("from_account") == "8027EC510") | (pl.col("to_account") == "8027EC510")) |
            ((pl.col("from_account") == "8025DCE40") | (pl.col("to_account") == "8025DCE40")) |
            ((pl.col("from_account") == "80AE37980") | (pl.col("to_account") == "80AE37980")) |
            ((pl.col("from_account") == "80EE67C20") | (pl.col("to_account") == "80EE67C20")) |
            ((pl.col("from_account") == "802C78C30") | (pl.col("to_account") == "802C78C30")) |
            ((pl.col("from_account") == "801402460") | (pl.col("to_account") == "801402460")) |
            ((pl.col("from_account") == "8060B8CF0") | (pl.col("to_account") == "8060B8CF0")) |
            ((pl.col("from_account") == "8070AC5B0") | (pl.col("to_account") == "8070AC5B0")) |
            ((pl.col("from_account") == "80EFADF00") | (pl.col("to_account") == "80EFADF00")) |
            ((pl.col("from_account") == "803B194C0") | (pl.col("to_account") == "803B194C0")) |
            ((pl.col("from_account") == "80FDF7CB0") | (pl.col("to_account") == "80FDF7CB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80F3ACA20") | (pl.col("to_account") == "80F3ACA20")) |
            ((pl.col("from_account") == "8095D1790") | (pl.col("to_account") == "8095D1790")) |
            ((pl.col("from_account") == "80B46B3D0") | (pl.col("to_account") == "80B46B3D0")) |
            ((pl.col("from_account") == "8063DFCD0") | (pl.col("to_account") == "8063DFCD0")) |
            ((pl.col("from_account") == "80982E450") | (pl.col("to_account") == "80982E450")) |
            ((pl.col("from_account") == "804E82A60") | (pl.col("to_account") == "804E82A60")) |
            ((pl.col("from_account") == "8069C3920") | (pl.col("to_account") == "8069C3920")) |
            ((pl.col("from_account") == "80FBC0EE0") | (pl.col("to_account") == "80FBC0EE0")) |
            ((pl.col("from_account") == "804BDD750") | (pl.col("to_account") == "804BDD750"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "801823D10") | (pl.col("to_account") == "801823D10")) |
            ((pl.col("from_account") == "80242A960") | (pl.col("to_account") == "80242A960")) |
            ((pl.col("from_account") == "807F1F4F0") | (pl.col("to_account") == "807F1F4F0")) |
            ((pl.col("from_account") == "80806B1D0") | (pl.col("to_account") == "80806B1D0")) |
            ((pl.col("from_account") == "8092F21D0") | (pl.col("to_account") == "8092F21D0")) |
            ((pl.col("from_account") == "801F12A80") | (pl.col("to_account") == "801F12A80")) |
            ((pl.col("from_account") == "804152B40") | (pl.col("to_account") == "804152B40")) |
            ((pl.col("from_account") == "80758D4D0") | (pl.col("to_account") == "80758D4D0")) |
            ((pl.col("from_account") == "8024DF2F0") | (pl.col("to_account") == "8024DF2F0")) |
            ((pl.col("from_account") == "80B76B210") | (pl.col("to_account") == "80B76B210")) |
            ((pl.col("from_account") == "8069B8F70") | (pl.col("to_account") == "8069B8F70")) |
            ((pl.col("from_account") == "8010AE030") | (pl.col("to_account") == "8010AE030")) |
            ((pl.col("from_account") == "804B56250") | (pl.col("to_account") == "804B56250")) |
            ((pl.col("from_account") == "807C35490") | (pl.col("to_account") == "807C35490")) |
            ((pl.col("from_account") == "8079CFBF0") | (pl.col("to_account") == "8079CFBF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "800859800") | (pl.col("to_account") == "800859800")) |
            ((pl.col("from_account") == "8004D8EA0") | (pl.col("to_account") == "8004D8EA0")) |
            ((pl.col("from_account") == "800E84250") | (pl.col("to_account") == "800E84250")) |
            ((pl.col("from_account") == "8006F8830") | (pl.col("to_account") == "8006F8830")) |
            ((pl.col("from_account") == "80187AF80") | (pl.col("to_account") == "80187AF80")) |
            ((pl.col("from_account") == "801D86260") | (pl.col("to_account") == "801D86260")) |
            ((pl.col("from_account") == "8016221C0") | (pl.col("to_account") == "8016221C0")) |
            ((pl.col("from_account") == "8019ACB80") | (pl.col("to_account") == "8019ACB80")) |
            ((pl.col("from_account") == "8014E2420") | (pl.col("to_account") == "8014E2420")) |
            ((pl.col("from_account") == "80104C350") | (pl.col("to_account") == "80104C350")) |
            ((pl.col("from_account") == "8013F7460") | (pl.col("to_account") == "8013F7460")) |
            ((pl.col("from_account") == "801F819D0") | (pl.col("to_account") == "801F819D0")) |
            ((pl.col("from_account") == "80125D6D0") | (pl.col("to_account") == "80125D6D0")) |
            ((pl.col("from_account") == "801A3CC30") | (pl.col("to_account") == "801A3CC30")) |
            ((pl.col("from_account") == "801CAED50") | (pl.col("to_account") == "801CAED50")) |
            ((pl.col("from_account") == "801318F70") | (pl.col("to_account") == "801318F70")) |
            ((pl.col("from_account") == "8012DE8D0") | (pl.col("to_account") == "8012DE8D0")) |
            ((pl.col("from_account") == "800B11170") | (pl.col("to_account") == "800B11170")) |
            ((pl.col("from_account") == "800A54A70") | (pl.col("to_account") == "800A54A70")) |
            ((pl.col("from_account") == "801CF2AD0") | (pl.col("to_account") == "801CF2AD0")) |
            ((pl.col("from_account") == "8018C3110") | (pl.col("to_account") == "8018C3110")) |
            ((pl.col("from_account") == "8000E0CA0") | (pl.col("to_account") == "8000E0CA0")) |
            ((pl.col("from_account") == "801C0A920") | (pl.col("to_account") == "801C0A920"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "801A1E020") | (pl.col("to_account") == "801A1E020")) |
            ((pl.col("from_account") == "80C48F890") | (pl.col("to_account") == "80C48F890")) |
            ((pl.col("from_account") == "805ED9330") | (pl.col("to_account") == "805ED9330")) |
            ((pl.col("from_account") == "8025E28D0") | (pl.col("to_account") == "8025E28D0")) |
            ((pl.col("from_account") == "8015936C0") | (pl.col("to_account") == "8015936C0")) |
            ((pl.col("from_account") == "80FE11FA0") | (pl.col("to_account") == "80FE11FA0")) |
            ((pl.col("from_account") == "80A110B80") | (pl.col("to_account") == "80A110B80")) |
            ((pl.col("from_account") == "80DFB9AD0") | (pl.col("to_account") == "80DFB9AD0")) |
            ((pl.col("from_account") == "807049450") | (pl.col("to_account") == "807049450")) |
            ((pl.col("from_account") == "806E1E420") | (pl.col("to_account") == "806E1E420")) |
            ((pl.col("from_account") == "802374C40") | (pl.col("to_account") == "802374C40")) |
            ((pl.col("from_account") == "808F74570") | (pl.col("to_account") == "808F74570")) |
            ((pl.col("from_account") == "80C2E5A90") | (pl.col("to_account") == "80C2E5A90")) |
            ((pl.col("from_account") == "808E2DDF0") | (pl.col("to_account") == "808E2DDF0")) |
            ((pl.col("from_account") == "80A6CED00") | (pl.col("to_account") == "80A6CED00")) |
            ((pl.col("from_account") == "808B43660") | (pl.col("to_account") == "808B43660")) |
            ((pl.col("from_account") == "801A4DCF0") | (pl.col("to_account") == "801A4DCF0")) |
            ((pl.col("from_account") == "80055FEA0") | (pl.col("to_account") == "80055FEA0")) |
            ((pl.col("from_account") == "80595BED0") | (pl.col("to_account") == "80595BED0")) |
            ((pl.col("from_account") == "80BED30D0") | (pl.col("to_account") == "80BED30D0")) |
            ((pl.col("from_account") == "80261A170") | (pl.col("to_account") == "80261A170")) |
            ((pl.col("from_account") == "80600C430") | (pl.col("to_account") == "80600C430")) |
            ((pl.col("from_account") == "800146B60") | (pl.col("to_account") == "800146B60")) |
            ((pl.col("from_account") == "8037983D0") | (pl.col("to_account") == "8037983D0")) |
            ((pl.col("from_account") == "8095C19A0") | (pl.col("to_account") == "8095C19A0")) |
            ((pl.col("from_account") == "8084903D0") | (pl.col("to_account") == "8084903D0")) |
            ((pl.col("from_account") == "80615B420") | (pl.col("to_account") == "80615B420")) |
            ((pl.col("from_account") == "8067B9300") | (pl.col("to_account") == "8067B9300")) |
            ((pl.col("from_account") == "8019856D0") | (pl.col("to_account") == "8019856D0")) |
            ((pl.col("from_account") == "80625B770") | (pl.col("to_account") == "80625B770")) |
            ((pl.col("from_account") == "80A7733F0") | (pl.col("to_account") == "80A7733F0")) |
            ((pl.col("from_account") == "808361B30") | (pl.col("to_account") == "808361B30")) |
            ((pl.col("from_account") == "80178FAA0") | (pl.col("to_account") == "80178FAA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))


    .when(
        (
            ((pl.col("from_account") == "801B6D270") | (pl.col("to_account") == "801B6D270")) |
            ((pl.col("from_account") == "8010BB4D0") | (pl.col("to_account") == "8010BB4D0")) |
            ((pl.col("from_account") == "80A9D7A10") | (pl.col("to_account") == "80A9D7A10")) |
            ((pl.col("from_account") == "801B81AB0") | (pl.col("to_account") == "801B81AB0")) |
            ((pl.col("from_account") == "805566BB0") | (pl.col("to_account") == "805566BB0")) |
            ((pl.col("from_account") == "80549CF00") | (pl.col("to_account") == "80549CF00")) |
            ((pl.col("from_account") == "80B3A0080") | (pl.col("to_account") == "80B3A0080")) |
            ((pl.col("from_account") == "80096F760") | (pl.col("to_account") == "80096F760")) |
            ((pl.col("from_account") == "802D94F50") | (pl.col("to_account") == "802D94F50")) |
            ((pl.col("from_account") == "80019D2E0") | (pl.col("to_account") == "80019D2E0")) |
            ((pl.col("from_account") == "80E2F27A0") | (pl.col("to_account") == "80E2F27A0")) |
            ((pl.col("from_account") == "8087F0BB0") | (pl.col("to_account") == "8087F0BB0")) |
            ((pl.col("from_account") == "803E2DFF0") | (pl.col("to_account") == "803E2DFF0")) |
            ((pl.col("from_account") == "801368CE0") | (pl.col("to_account") == "801368CE0")) |
            ((pl.col("from_account") == "80F540750") | (pl.col("to_account") == "80F540750")) |
            ((pl.col("from_account") == "803290610") | (pl.col("to_account") == "803290610")) |
            ((pl.col("from_account") == "80C5CA5C0") | (pl.col("to_account") == "80C5CA5C0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))


    .when(
        (
            ((pl.col("from_account") == "80011B370") | (pl.col("to_account") == "80011B370")) |
            ((pl.col("from_account") == "800164D30") | (pl.col("to_account") == "800164D30")) |
            ((pl.col("from_account") == "8000EFAA0") | (pl.col("to_account") == "8000EFAA0")) |
            ((pl.col("from_account") == "8001BD460") | (pl.col("to_account") == "8001BD460")) |
            ((pl.col("from_account") == "80050C9D0") | (pl.col("to_account") == "80050C9D0")) |
            ((pl.col("from_account") == "80012EBD0") | (pl.col("to_account") == "80012EBD0")) |
            ((pl.col("from_account") == "80018E990") | (pl.col("to_account") == "80018E990")) |
            ((pl.col("from_account") == "800059C00") | (pl.col("to_account") == "800059C00")) |
            ((pl.col("from_account") == "800165A30") | (pl.col("to_account") == "800165A30")) |
            ((pl.col("from_account") == "80010BFC0") | (pl.col("to_account") == "80010BFC0")) |
            ((pl.col("from_account") == "8000EC7E0") | (pl.col("to_account") == "8000EC7E0")) |
            ((pl.col("from_account") == "80029B9F0") | (pl.col("to_account") == "80029B9F0")) |
            ((pl.col("from_account") == "8008B79A0") | (pl.col("to_account") == "8008B79A0")) |
            ((pl.col("from_account") == "8002BCF50") | (pl.col("to_account") == "8002BCF50")) |
            ((pl.col("from_account") == "800241D60") | (pl.col("to_account") == "800241D60")) |
            ((pl.col("from_account") == "8000F9560") | (pl.col("to_account") == "8000F9560")) |
            ((pl.col("from_account") == "800240F70") | (pl.col("to_account") == "800240F70")) |
            ((pl.col("from_account") == "800120A50") | (pl.col("to_account") == "800120A50"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8083724D0") | (pl.col("to_account") == "8083724D0")) |
            ((pl.col("from_account") == "808A58D40") | (pl.col("to_account") == "808A58D40")) |
            ((pl.col("from_account") == "80A8A0F70") | (pl.col("to_account") == "80A8A0F70")) |
            ((pl.col("from_account") == "80E6D8130") | (pl.col("to_account") == "80E6D8130")) |
            ((pl.col("from_account") == "80F1FBAD0") | (pl.col("to_account") == "80F1FBAD0")) |
            ((pl.col("from_account") == "8048CB7A0") | (pl.col("to_account") == "8048CB7A0")) |
            ((pl.col("from_account") == "8018514B0") | (pl.col("to_account") == "8018514B0")) |
            ((pl.col("from_account") == "80AA72BA0") | (pl.col("to_account") == "80AA72BA0")) |
            ((pl.col("from_account") == "8022AF930") | (pl.col("to_account") == "8022AF930")) |
            ((pl.col("from_account") == "8034C0D20") | (pl.col("to_account") == "8034C0D20")) |
            ((pl.col("from_account") == "804A8A480") | (pl.col("to_account") == "804A8A480")) |
            ((pl.col("from_account") == "80C5C01D0") | (pl.col("to_account") == "80C5C01D0")) |
            ((pl.col("from_account") == "8047DE090") | (pl.col("to_account") == "8047DE090")) |
            ((pl.col("from_account") == "80254C330") | (pl.col("to_account") == "80254C330")) |
            ((pl.col("from_account") == "8046778F0") | (pl.col("to_account") == "8046778F0")) |
            ((pl.col("from_account") == "8063A29D0") | (pl.col("to_account") == "8063A29D0")) |
            ((pl.col("from_account") == "801BDCE30") | (pl.col("to_account") == "801BDCE30")) |
            ((pl.col("from_account") == "80B616540") | (pl.col("to_account") == "80B616540")) |
            ((pl.col("from_account") == "800EEECD0") | (pl.col("to_account") == "800EEECD0")) |
            ((pl.col("from_account") == "804AD1FB0") | (pl.col("to_account") == "804AD1FB0")) |
            ((pl.col("from_account") == "80DE65350") | (pl.col("to_account") == "80DE65350")) |
            ((pl.col("from_account") == "80A9E82B0") | (pl.col("to_account") == "80A9E82B0")) |
            ((pl.col("from_account") == "80BB81D50") | (pl.col("to_account") == "80BB81D50")) |
            ((pl.col("from_account") == "807E80300") | (pl.col("to_account") == "807E80300")) |
            ((pl.col("from_account") == "8088E9DA0") | (pl.col("to_account") == "8088E9DA0")) |
            ((pl.col("from_account") == "80CBA63F0") | (pl.col("to_account") == "80CBA63F0")) |
            ((pl.col("from_account") == "8019DE740") | (pl.col("to_account") == "8019DE740")) |
            ((pl.col("from_account") == "80EA18C20") | (pl.col("to_account") == "80EA18C20")) |
            ((pl.col("from_account") == "80BB90E90") | (pl.col("to_account") == "80BB90E90")) |
            ((pl.col("from_account") == "80C1C49F0") | (pl.col("to_account") == "80C1C49F0")) |
            ((pl.col("from_account") == "80D3F0070") | (pl.col("to_account") == "80D3F0070")) |
            ((pl.col("from_account") == "80C88C950") | (pl.col("to_account") == "80C88C950")) |
            ((pl.col("from_account") == "80B9BD900") | (pl.col("to_account") == "80B9BD900")) |
            ((pl.col("from_account") == "80CB230F0") | (pl.col("to_account") == "80CB230F0")) |
            ((pl.col("from_account") == "803D8E3A0") | (pl.col("to_account") == "803D8E3A0")) |
            ((pl.col("from_account") == "80FCBD920") | (pl.col("to_account") == "80FCBD920")) |
            ((pl.col("from_account") == "80BC94290") | (pl.col("to_account") == "80BC94290")) |
            ((pl.col("from_account") == "801314930") | (pl.col("to_account") == "801314930")) |
            ((pl.col("from_account") == "804ABF900") | (pl.col("to_account") == "804ABF900")) |
            ((pl.col("from_account") == "807B751B0") | (pl.col("to_account") == "807B751B0")) |
            ((pl.col("from_account") == "8094502D0") | (pl.col("to_account") == "8094502D0")) |
            ((pl.col("from_account") == "80B6EACF0") | (pl.col("to_account") == "80B6EACF0")) |
            ((pl.col("from_account") == "800C68D20") | (pl.col("to_account") == "800C68D20")) |
            ((pl.col("from_account") == "8007C5C80") | (pl.col("to_account") == "8007C5C80")) |
            ((pl.col("from_account") == "8069CC590") | (pl.col("to_account") == "8069CC590"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "808DB6D10") | (pl.col("to_account") == "808DB6D10")) |
            ((pl.col("from_account") == "80068DB50") | (pl.col("to_account") == "80068DB50")) |
            ((pl.col("from_account") == "806A20680") | (pl.col("to_account") == "806A20680")) |
            ((pl.col("from_account") == "80B7E71D0") | (pl.col("to_account") == "80B7E71D0")) |
            ((pl.col("from_account") == "803D6C480") | (pl.col("to_account") == "803D6C480")) |
            ((pl.col("from_account") == "80477A740") | (pl.col("to_account") == "80477A740")) |
            ((pl.col("from_account") == "80A41A7D0") | (pl.col("to_account") == "80A41A7D0")) |
            ((pl.col("from_account") == "804E3A720") | (pl.col("to_account") == "804E3A720")) |
            ((pl.col("from_account") == "805C34090") | (pl.col("to_account") == "805C34090")) |
            ((pl.col("from_account") == "8001D71F0") | (pl.col("to_account") == "8001D71F0")) |
            ((pl.col("from_account") == "80813D810") | (pl.col("to_account") == "80813D810")) |
            ((pl.col("from_account") == "80EAED430") | (pl.col("to_account") == "80EAED430")) |
            ((pl.col("from_account") == "80CAD99F0") | (pl.col("to_account") == "80CAD99F0")) |
            ((pl.col("from_account") == "80C25CC60") | (pl.col("to_account") == "80C25CC60")) |
            ((pl.col("from_account") == "803D208B0") | (pl.col("to_account") == "803D208B0")) |
            ((pl.col("from_account") == "811D34B50") | (pl.col("to_account") == "811D34B50")) |
            ((pl.col("from_account") == "803601230") | (pl.col("to_account") == "803601230")) |
            ((pl.col("from_account") == "80A0C9030") | (pl.col("to_account") == "80A0C9030")) |
            ((pl.col("from_account") == "8019EA660") | (pl.col("to_account") == "8019EA660")) |
            ((pl.col("from_account") == "803F94070") | (pl.col("to_account") == "803F94070")) |
            ((pl.col("from_account") == "806E6FE50") | (pl.col("to_account") == "806E6FE50")) |
            ((pl.col("from_account") == "80146B800") | (pl.col("to_account") == "80146B800")) |
            ((pl.col("from_account") == "8103A5AF0") | (pl.col("to_account") == "8103A5AF0")) |
            ((pl.col("from_account") == "803726250") | (pl.col("to_account") == "803726250"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8001B3D10") | (pl.col("to_account") == "8001B3D10")) |
            ((pl.col("from_account") == "8001BA1D0") | (pl.col("to_account") == "8001BA1D0")) |
            ((pl.col("from_account") == "800103610") | (pl.col("to_account") == "800103610")) |
            ((pl.col("from_account") == "8001325C0") | (pl.col("to_account") == "8001325C0")) |
            ((pl.col("from_account") == "8001D6370") | (pl.col("to_account") == "8001D6370")) |
            ((pl.col("from_account") == "800058470") | (pl.col("to_account") == "800058470")) |
            ((pl.col("from_account") == "8001BC960") | (pl.col("to_account") == "8001BC960")) |
            ((pl.col("from_account") == "8001FCB30") | (pl.col("to_account") == "8001FCB30")) |
            ((pl.col("from_account") == "80023BB50") | (pl.col("to_account") == "80023BB50")) |
            ((pl.col("from_account") == "800963A91") | (pl.col("to_account") == "800963A91")) |
            ((pl.col("from_account") == "8000E43B1") | (pl.col("to_account") == "8000E43B1")) |
            ((pl.col("from_account") == "8000E43B0") | (pl.col("to_account") == "8000E43B0")) |
            ((pl.col("from_account") == "8001B4210") | (pl.col("to_account") == "8001B4210")) |
            ((pl.col("from_account") == "80005BD00") | (pl.col("to_account") == "80005BD00")) |
            ((pl.col("from_account") == "8000F65C0") | (pl.col("to_account") == "8000F65C0")) |
            ((pl.col("from_account") == "800142410") | (pl.col("to_account") == "800142410"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80A784730") | (pl.col("to_account") == "80A784730")) |
            ((pl.col("from_account") == "8113D8850") | (pl.col("to_account") == "8113D8850")) |
            ((pl.col("from_account") == "811AB7660") | (pl.col("to_account") == "811AB7660")) |
            ((pl.col("from_account") == "80A9194B0") | (pl.col("to_account") == "80A9194B0")) |
            ((pl.col("from_account") == "807AE3400") | (pl.col("to_account") == "807AE3400")) |
            ((pl.col("from_account") == "803C95E70") | (pl.col("to_account") == "803C95E70")) |
            ((pl.col("from_account") == "8008AF700") | (pl.col("to_account") == "8008AF700")) |
            ((pl.col("from_account") == "810E34C30") | (pl.col("to_account") == "810E34C30")) |
            ((pl.col("from_account") == "80D4AA440") | (pl.col("to_account") == "80D4AA440")) |
            ((pl.col("from_account") == "80A757530") | (pl.col("to_account") == "80A757530")) |
            ((pl.col("from_account") == "809DCF810") | (pl.col("to_account") == "809DCF810")) |
            ((pl.col("from_account") == "805044D20") | (pl.col("to_account") == "805044D20")) |
            ((pl.col("from_account") == "8047210A0") | (pl.col("to_account") == "8047210A0")) |
            ((pl.col("from_account") == "80465E720") | (pl.col("to_account") == "80465E720")) |
            ((pl.col("from_account") == "80E4864B0") | (pl.col("to_account") == "80E4864B0")) |
            ((pl.col("from_account") == "8033CA2E0") | (pl.col("to_account") == "8033CA2E0")) |
            ((pl.col("from_account") == "806E0F510") | (pl.col("to_account") == "806E0F510")) |
            ((pl.col("from_account") == "810F60C80") | (pl.col("to_account") == "810F60C80")) |
            ((pl.col("from_account") == "811D70040") | (pl.col("to_account") == "811D70040")) |
            ((pl.col("from_account") == "80239A430") | (pl.col("to_account") == "80239A430"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80812E970") | (pl.col("to_account") == "80812E970")) |
            ((pl.col("from_account") == "80890A8B0") | (pl.col("to_account") == "80890A8B0")) |
            ((pl.col("from_account") == "804EF2220") | (pl.col("to_account") == "804EF2220")) |
            ((pl.col("from_account") == "803B90890") | (pl.col("to_account") == "803B90890")) |
            ((pl.col("from_account") == "804A23160") | (pl.col("to_account") == "804A23160")) |
            ((pl.col("from_account") == "804791210") | (pl.col("to_account") == "804791210")) |
            ((pl.col("from_account") == "804070990") | (pl.col("to_account") == "804070990")) |
            ((pl.col("from_account") == "80923D480") | (pl.col("to_account") == "80923D480")) |
            ((pl.col("from_account") == "80148AA00") | (pl.col("to_account") == "80148AA00")) |
            ((pl.col("from_account") == "801F86B70") | (pl.col("to_account") == "801F86B70")) |
            ((pl.col("from_account") == "8005CC8D0") | (pl.col("to_account") == "8005CC8D0")) |
            ((pl.col("from_account") == "803BE1900") | (pl.col("to_account") == "803BE1900")) |
            ((pl.col("from_account") == "8031C17D0") | (pl.col("to_account") == "8031C17D0")) |
            ((pl.col("from_account") == "808760660") | (pl.col("to_account") == "808760660")) |
            ((pl.col("from_account") == "805A8E1E0") | (pl.col("to_account") == "805A8E1E0")) |
            ((pl.col("from_account") == "802BE7350") | (pl.col("to_account") == "802BE7350")) |
            ((pl.col("from_account") == "801280800") | (pl.col("to_account") == "801280800")) |
            ((pl.col("from_account") == "8091B5A10") | (pl.col("to_account") == "8091B5A10")) |
            ((pl.col("from_account") == "803E18A10") | (pl.col("to_account") == "803E18A10")) |
            ((pl.col("from_account") == "80704ACD0") | (pl.col("to_account") == "80704ACD0")) |
            ((pl.col("from_account") == "8078349F0") | (pl.col("to_account") == "8078349F0")) |
            ((pl.col("from_account") == "803A1BB50") | (pl.col("to_account") == "803A1BB50")) |
            ((pl.col("from_account") == "8018AB540") | (pl.col("to_account") == "8018AB540")) |
            ((pl.col("from_account") == "802710FF0") | (pl.col("to_account") == "802710FF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8035D5A00") | (pl.col("to_account") == "8035D5A00")) |
            ((pl.col("from_account") == "81095BC00") | (pl.col("to_account") == "81095BC00")) |
            ((pl.col("from_account") == "803FAA9E0") | (pl.col("to_account") == "803FAA9E0")) |
            ((pl.col("from_account") == "800568E00") | (pl.col("to_account") == "800568E00")) |
            ((pl.col("from_account") == "8010D1180") | (pl.col("to_account") == "8010D1180")) |
            ((pl.col("from_account") == "808A02960") | (pl.col("to_account") == "808A02960")) |
            ((pl.col("from_account") == "808D6DF20") | (pl.col("to_account") == "808D6DF20")) |
            ((pl.col("from_account") == "80498D100") | (pl.col("to_account") == "80498D100")) |
            ((pl.col("from_account") == "8095843D0") | (pl.col("to_account") == "8095843D0")) |
            ((pl.col("from_account") == "804642430") | (pl.col("to_account") == "804642430")) |
            ((pl.col("from_account") == "80BFE6D70") | (pl.col("to_account") == "80BFE6D70")) |
            ((pl.col("from_account") == "8028CF9A0") | (pl.col("to_account") == "8028CF9A0")) |
            ((pl.col("from_account") == "80C166500") | (pl.col("to_account") == "80C166500")) |
            ((pl.col("from_account") == "806B553D0") | (pl.col("to_account") == "806B553D0")) |
            ((pl.col("from_account") == "80F0A2660") | (pl.col("to_account") == "80F0A2660")) |
            ((pl.col("from_account") == "80E22F4F0") | (pl.col("to_account") == "80E22F4F0")) |
            ((pl.col("from_account") == "80E1B9E30") | (pl.col("to_account") == "80E1B9E30")) |
            ((pl.col("from_account") == "80DEBE6D0") | (pl.col("to_account") == "80DEBE6D0")) |
            ((pl.col("from_account") == "80171BB30") | (pl.col("to_account") == "80171BB30")) |
            ((pl.col("from_account") == "8079A4BF0") | (pl.col("to_account") == "8079A4BF0")) |
            ((pl.col("from_account") == "8079B1920") | (pl.col("to_account") == "8079B1920"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "8027E6880") | (pl.col("to_account") == "8027E6880")) |
            ((pl.col("from_account") == "80468CA80") | (pl.col("to_account") == "80468CA80")) |
            ((pl.col("from_account") == "80F2398D0") | (pl.col("to_account") == "80F2398D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    .when(
        (
            ((pl.col("from_account") == "80C97F160") | (pl.col("to_account") == "80C97F160")) |
            ((pl.col("from_account") == "80BD30B70") | (pl.col("to_account") == "80BD30B70")) |
            ((pl.col("from_account") == "80DE5F400") | (pl.col("to_account") == "80DE5F400")) |
            ((pl.col("from_account") == "801BB7D10") | (pl.col("to_account") == "801BB7D10")) |
            ((pl.col("from_account") == "808444690") | (pl.col("to_account") == "808444690")) |
            ((pl.col("from_account") == "80C77C800") | (pl.col("to_account") == "80C77C800")) |
            ((pl.col("from_account") == "805A507F0") | (pl.col("to_account") == "805A507F0")) |
            ((pl.col("from_account") == "80E3C0300") | (pl.col("to_account") == "80E3C0300")) |
            ((pl.col("from_account") == "808FD5CA0") | (pl.col("to_account") == "808FD5CA0")) |
            ((pl.col("from_account") == "80F1404E0") | (pl.col("to_account") == "80F1404E0")) |
            ((pl.col("from_account") == "8025D1EB0") | (pl.col("to_account") == "8025D1EB0")) |
            ((pl.col("from_account") == "803C925B0") | (pl.col("to_account") == "803C925B0")) |
            ((pl.col("from_account") == "809F26890") | (pl.col("to_account") == "809F26890")) |
            ((pl.col("from_account") == "8083CF250") | (pl.col("to_account") == "8083CF250")) |
            ((pl.col("from_account") == "809406BF0") | (pl.col("to_account") == "809406BF0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(5))

    

    






        
        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 5)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as stack: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as stack: 471
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 223       ┆ 8000DD890    ┆ 40312   ┆ 80F52D550  ┆ 1             ┆ 5       │
# │ 40312     ┆ 80F52D550    ┆ 23370   ┆ 80BEA98A0  ┆ 1             ┆ 5       │
# │ 18617     ┆ 8038D3520    ┆ 24482   ┆ 801C0F2B0  ┆ 1             ┆ 5       │
# │ 24482     ┆ 801C0F2B0    ┆ 214     ┆ 80C1B9E20  ┆ 1             ┆ 5       │
# │ 40836     ┆ 80F6B88B0    ┆ 16606   ┆ 8064545E0  ┆ 1             ┆ 5       │
# │ 16606     ┆ 8064545E0    ┆ 2454    ┆ 80662A070  ┆ 1             ┆ 5       │
# ...

# %% [markdown]
# ### Bipartite

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_account") == "80103A420") | (pl.col("to_account") == "80103A420")) |
            ((pl.col("from_account") == "802533E40") | (pl.col("to_account") == "802533E40")) |
            ((pl.col("from_account") == "80211F620") | (pl.col("to_account") == "80211F620")) |
            ((pl.col("from_account") == "8019C6830") | (pl.col("to_account") == "8019C6830")) |
            ((pl.col("from_account") == "800A75B90") | (pl.col("to_account") == "800A75B90")) |
            ((pl.col("from_account") == "80162B4B0") | (pl.col("to_account") == "80162B4B0")) |
            ((pl.col("from_account") == "8010AA4F0") | (pl.col("to_account") == "8010AA4F0")) |
            ((pl.col("from_account") == "8015B5F50") | (pl.col("to_account") == "8015B5F50")) |
            ((pl.col("from_account") == "800DD9900") | (pl.col("to_account") == "800DD9900")) |
            ((pl.col("from_account") == "8006F0580") | (pl.col("to_account") == "8006F0580")) |
            ((pl.col("from_account") == "800587B60") | (pl.col("to_account") == "800587B60")) |
            ((pl.col("from_account") == "802679190") | (pl.col("to_account") == "802679190")) |
            ((pl.col("from_account") == "801947FF0") | (pl.col("to_account") == "801947FF0")) |
            ((pl.col("from_account") == "800639010") | (pl.col("to_account") == "800639010")) |
            ((pl.col("from_account") == "800ACE160") | (pl.col("to_account") == "800ACE160")) |
            ((pl.col("from_account") == "800AEC6D0") | (pl.col("to_account") == "800AEC6D0")) |
            ((pl.col("from_account") == "8020543A0") | (pl.col("to_account") == "8020543A0")) |
            ((pl.col("from_account") == "8018DC000") | (pl.col("to_account") == "8018DC000")) |
            ((pl.col("from_account") == "801A58F80") | (pl.col("to_account") == "801A58F80")) |
            ((pl.col("from_account") == "80048D890") | (pl.col("to_account") == "80048D890")) |
            ((pl.col("from_account") == "800BBBEC0") | (pl.col("to_account") == "800BBBEC0")) |
            ((pl.col("from_account") == "801732D60") | (pl.col("to_account") == "801732D60")) |
            ((pl.col("from_account") == "8010647D0") | (pl.col("to_account") == "8010647D0")) |
            ((pl.col("from_account") == "801CFFF90") | (pl.col("to_account") == "801CFFF90")) |
            ((pl.col("from_account") == "801BA48E0") | (pl.col("to_account") == "801BA48E0")) |
            ((pl.col("from_account") == "80044F690") | (pl.col("to_account") == "80044F690"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))  # BIPARTITE
    .when(
        (
            ((pl.col("from_account") == "800C050D0") | (pl.col("to_account") == "800C050D0")) |
            ((pl.col("from_account") == "8044B4190") | (pl.col("to_account") == "8044B4190")) |
            ((pl.col("from_account") == "80CDF9CD0") | (pl.col("to_account") == "80CDF9CD0")) |
            ((pl.col("from_account") == "808838010") | (pl.col("to_account") == "808838010")) |
            ((pl.col("from_account") == "808E9DCD0") | (pl.col("to_account") == "808E9DCD0")) |
            ((pl.col("from_account") == "811F91690") | (pl.col("to_account") == "811F91690")) |
            ((pl.col("from_account") == "80A2953E0") | (pl.col("to_account") == "80A2953E0")) |
            ((pl.col("from_account") == "8021309A0") | (pl.col("to_account") == "8021309A0")) |
            ((pl.col("from_account") == "8102394B0") | (pl.col("to_account") == "8102394B0")) |
            ((pl.col("from_account") == "810DF3480") | (pl.col("to_account") == "810DF3480")) |
            ((pl.col("from_account") == "802958DB0") | (pl.col("to_account") == "802958DB0")) |
            ((pl.col("from_account") == "810E1A430") | (pl.col("to_account") == "810E1A430")) |
            ((pl.col("from_account") == "8015A3ED0") | (pl.col("to_account") == "8015A3ED0")) |
            ((pl.col("from_account") == "804DA7470") | (pl.col("to_account") == "804DA7470")) |
            ((pl.col("from_account") == "811FA3310") | (pl.col("to_account") == "811FA3310")) |
            ((pl.col("from_account") == "80932CC40") | (pl.col("to_account") == "80932CC40")) |
            ((pl.col("from_account") == "8083E2D60") | (pl.col("to_account") == "8083E2D60")) |
            ((pl.col("from_account") == "811DFB6B0") | (pl.col("to_account") == "811DFB6B0")) |
            ((pl.col("from_account") == "810FB7950") | (pl.col("to_account") == "810FB7950")) |
            ((pl.col("from_account") == "80445F940") | (pl.col("to_account") == "80445F940")) |
            ((pl.col("from_account") == "8047B6D80") | (pl.col("to_account") == "8047B6D80")) |
            ((pl.col("from_account") == "8090E3020") | (pl.col("to_account") == "8090E3020")) |
            ((pl.col("from_account") == "800A3E5A0") | (pl.col("to_account") == "800A3E5A0")) |
            ((pl.col("from_account") == "80DA83990") | (pl.col("to_account") == "80DA83990"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "8031FC940") | (pl.col("to_account") == "8031FC940")) |
            ((pl.col("from_account") == "8015C6BB0") | (pl.col("to_account") == "8015C6BB0")) |
            ((pl.col("from_account") == "802FFC060") | (pl.col("to_account") == "802FFC060")) |
            ((pl.col("from_account") == "802AD27C0") | (pl.col("to_account") == "802AD27C0")) |
            ((pl.col("from_account") == "8024DBCA0") | (pl.col("to_account") == "8024DBCA0")) |
            ((pl.col("from_account") == "807E3D970") | (pl.col("to_account") == "807E3D970")) |
            ((pl.col("from_account") == "800C15270") | (pl.col("to_account") == "800C15270")) |
            ((pl.col("from_account") == "8094155B0") | (pl.col("to_account") == "8094155B0")) |
            ((pl.col("from_account") == "80C627820") | (pl.col("to_account") == "80C627820")) |
            ((pl.col("from_account") == "8066D12D0") | (pl.col("to_account") == "8066D12D0")) |
            ((pl.col("from_account") == "801804D80") | (pl.col("to_account") == "801804D80")) |
            ((pl.col("from_account") == "80B81C1B0") | (pl.col("to_account") == "80B81C1B0")) |
            ((pl.col("from_account") == "8094AA6D0") | (pl.col("to_account") == "8094AA6D0")) |
            ((pl.col("from_account") == "8040B0040") | (pl.col("to_account") == "8040B0040")) |
            ((pl.col("from_account") == "80DFD0950") | (pl.col("to_account") == "80DFD0950")) |
            ((pl.col("from_account") == "808A026E0") | (pl.col("to_account") == "808A026E0")) |
            ((pl.col("from_account") == "80AE3D7E0") | (pl.col("to_account") == "80AE3D7E0")) |
            ((pl.col("from_account") == "802FACFC0") | (pl.col("to_account") == "802FACFC0")) |
            ((pl.col("from_account") == "804DBD7D0") | (pl.col("to_account") == "804DBD7D0")) |
            ((pl.col("from_account") == "805868B60") | (pl.col("to_account") == "805868B60")) |
            ((pl.col("from_account") == "80940A1D0") | (pl.col("to_account") == "80940A1D0")) |
            ((pl.col("from_account") == "80421CC70") | (pl.col("to_account") == "80421CC70"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "80F443FD0") | (pl.col("to_account") == "80F443FD0")) |
            ((pl.col("from_account") == "807697CA0") | (pl.col("to_account") == "807697CA0")) |
            ((pl.col("from_account") == "8091D1780") | (pl.col("to_account") == "8091D1780")) |
            ((pl.col("from_account") == "80662F8F0") | (pl.col("to_account") == "80662F8F0")) |
            ((pl.col("from_account") == "803F405F0") | (pl.col("to_account") == "803F405F0")) |
            ((pl.col("from_account") == "801C3C0D0") | (pl.col("to_account") == "801C3C0D0")) |
            ((pl.col("from_account") == "80C5AEED0") | (pl.col("to_account") == "80C5AEED0")) |
            ((pl.col("from_account") == "80B3748B0") | (pl.col("to_account") == "80B3748B0")) |
            ((pl.col("from_account") == "800181850") | (pl.col("to_account") == "800181850")) |
            ((pl.col("from_account") == "80A222330") | (pl.col("to_account") == "80A222330"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "8066C49A0") | (pl.col("to_account") == "8066C49A0")) |
            ((pl.col("from_account") == "804AEF9C0") | (pl.col("to_account") == "804AEF9C0")) |
            ((pl.col("from_account") == "80BBEB320") | (pl.col("to_account") == "80BBEB320")) |
            ((pl.col("from_account") == "80C3342B0") | (pl.col("to_account") == "80C3342B0")) |
            ((pl.col("from_account") == "8042509A0") | (pl.col("to_account") == "8042509A0")) |
            ((pl.col("from_account") == "809627A80") | (pl.col("to_account") == "809627A80")) |
            ((pl.col("from_account") == "800FB1BD0") | (pl.col("to_account") == "800FB1BD0")) |
            ((pl.col("from_account") == "801A53C00") | (pl.col("to_account") == "801A53C00")) |
            ((pl.col("from_account") == "801BB70D0") | (pl.col("to_account") == "801BB70D0")) |
            ((pl.col("from_account") == "80C90BBB0") | (pl.col("to_account") == "80C90BBB0")) |
            ((pl.col("from_account") == "8006619C0") | (pl.col("to_account") == "8006619C0")) |
            ((pl.col("from_account") == "805652E00") | (pl.col("to_account") == "805652E00")) |
            ((pl.col("from_account") == "80E870260") | (pl.col("to_account") == "80E870260")) |
            ((pl.col("from_account") == "80705A0E0") | (pl.col("to_account") == "80705A0E0")) |
            ((pl.col("from_account") == "80AAA1FE0") | (pl.col("to_account") == "80AAA1FE0")) |
            ((pl.col("from_account") == "8001ADC70") | (pl.col("to_account") == "8001ADC70")) |
            ((pl.col("from_account") == "80685EE50") | (pl.col("to_account") == "80685EE50")) |
            ((pl.col("from_account") == "80A440100") | (pl.col("to_account") == "80A440100")) |
            ((pl.col("from_account") == "80992E270") | (pl.col("to_account") == "80992E270")) |
            ((pl.col("from_account") == "806E9FF40") | (pl.col("to_account") == "806E9FF40")) |
            ((pl.col("from_account") == "805593540") | (pl.col("to_account") == "805593540")) |
            ((pl.col("from_account") == "802DABCA0") | (pl.col("to_account") == "802DABCA0")) |
            ((pl.col("from_account") == "80562E620") | (pl.col("to_account") == "80562E620")) |
            ((pl.col("from_account") == "803DBA190") | (pl.col("to_account") == "803DBA190")) |
            ((pl.col("from_account") == "80D4B5530") | (pl.col("to_account") == "80D4B5530")) |
            ((pl.col("from_account") == "801FA10A0") | (pl.col("to_account") == "801FA10A0")) |
            ((pl.col("from_account") == "802CDC780") | (pl.col("to_account") == "802CDC780")) |
            ((pl.col("from_account") == "8072203B0") | (pl.col("to_account") == "8072203B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "800E9F790") | (pl.col("to_account") == "800E9F790")) |
            ((pl.col("from_account") == "8003541A0") | (pl.col("to_account") == "8003541A0")) |
            ((pl.col("from_account") == "801DA76D0") | (pl.col("to_account") == "801DA76D0")) |
            ((pl.col("from_account") == "80172F250") | (pl.col("to_account") == "80172F250")) |
            ((pl.col("from_account") == "80147E520") | (pl.col("to_account") == "80147E520")) |
            ((pl.col("from_account") == "801F9F230") | (pl.col("to_account") == "801F9F230")) |
            ((pl.col("from_account") == "8011A5230") | (pl.col("to_account") == "8011A5230")) |
            ((pl.col("from_account") == "801E4BEA0") | (pl.col("to_account") == "801E4BEA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "8066CFF40") | (pl.col("to_account") == "8066CFF40")) |
            ((pl.col("from_account") == "807E86500") | (pl.col("to_account") == "807E86500")) |
            ((pl.col("from_account") == "80D476950") | (pl.col("to_account") == "80D476950")) |
            ((pl.col("from_account") == "800D75DA0") | (pl.col("to_account") == "800D75DA0")) |
            ((pl.col("from_account") == "8006E4A40") | (pl.col("to_account") == "8006E4A40")) |
            ((pl.col("from_account") == "802DD7890") | (pl.col("to_account") == "802DD7890")) |
            ((pl.col("from_account") == "80526F4E0") | (pl.col("to_account") == "80526F4E0")) |
            ((pl.col("from_account") == "8012BD570") | (pl.col("to_account") == "8012BD570")) |
            ((pl.col("from_account") == "8011D5060") | (pl.col("to_account") == "8011D5060")) |
            ((pl.col("from_account") == "8014FA230") | (pl.col("to_account") == "8014FA230")) |
            ((pl.col("from_account") == "80E290080") | (pl.col("to_account") == "80E290080")) |
            ((pl.col("from_account") == "806D9B280") | (pl.col("to_account") == "806D9B280"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "8054D6140") | (pl.col("to_account") == "8054D6140")) |
            ((pl.col("from_account") == "80181D8D0") | (pl.col("to_account") == "80181D8D0")) |
            ((pl.col("from_account") == "8094098D0") | (pl.col("to_account") == "8094098D0")) |
            ((pl.col("from_account") == "804E76250") | (pl.col("to_account") == "804E76250")) |
            ((pl.col("from_account") == "80E130380") | (pl.col("to_account") == "80E130380")) |
            ((pl.col("from_account") == "8030DF720") | (pl.col("to_account") == "8030DF720")) |
            ((pl.col("from_account") == "8109F5680") | (pl.col("to_account") == "8109F5680")) |
            ((pl.col("from_account") == "80B309660") | (pl.col("to_account") == "80B309660")) |
            ((pl.col("from_account") == "807193CC0") | (pl.col("to_account") == "807193CC0")) |
            ((pl.col("from_account") == "806800100") | (pl.col("to_account") == "806800100")) |
            ((pl.col("from_account") == "80767CAF0") | (pl.col("to_account") == "80767CAF0")) |
            ((pl.col("from_account") == "80278F960") | (pl.col("to_account") == "80278F960")) |
            ((pl.col("from_account") == "8091A9AE0") | (pl.col("to_account") == "8091A9AE0")) |
            ((pl.col("from_account") == "800FB6D00") | (pl.col("to_account") == "800FB6D00")) |
            ((pl.col("from_account") == "810088D50") | (pl.col("to_account") == "810088D50")) |
            ((pl.col("from_account") == "80B260AE0") | (pl.col("to_account") == "80B260AE0")) |
            ((pl.col("from_account") == "807C36910") | (pl.col("to_account") == "807C36910")) |
            ((pl.col("from_account") == "8028D57C0") | (pl.col("to_account") == "8028D57C0")) |
            ((pl.col("from_account") == "8080FB6B0") | (pl.col("to_account") == "8080FB6B0")) |
            ((pl.col("from_account") == "8002C7A50") | (pl.col("to_account") == "8002C7A50")) |
            ((pl.col("from_account") == "80CE3D700") | (pl.col("to_account") == "80CE3D700")) |
            ((pl.col("from_account") == "8003159D0") | (pl.col("to_account") == "8003159D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "80211CB70") | (pl.col("to_account") == "80211CB70")) |
            ((pl.col("from_account") == "8080B08A0") | (pl.col("to_account") == "8080B08A0")) |
            ((pl.col("from_account") == "800D9DA40") | (pl.col("to_account") == "800D9DA40")) |
            ((pl.col("from_account") == "80996C170") | (pl.col("to_account") == "80996C170")) |
            ((pl.col("from_account") == "80A6C74F0") | (pl.col("to_account") == "80A6C74F0")) |
            ((pl.col("from_account") == "808595F50") | (pl.col("to_account") == "808595F50")) |
            ((pl.col("from_account") == "809925180") | (pl.col("to_account") == "809925180")) |
            ((pl.col("from_account") == "8004375A0") | (pl.col("to_account") == "8004375A0")) |
            ((pl.col("from_account") == "80ED3C650") | (pl.col("to_account") == "80ED3C650")) |
            ((pl.col("from_account") == "8018DB540") | (pl.col("to_account") == "8018DB540")) |
            ((pl.col("from_account") == "80CF52AB0") | (pl.col("to_account") == "80CF52AB0")) |
            ((pl.col("from_account") == "806D73DD0") | (pl.col("to_account") == "806D73DD0")) |
            ((pl.col("from_account") == "80DEA1270") | (pl.col("to_account") == "80DEA1270")) |
            ((pl.col("from_account") == "80661C800") | (pl.col("to_account") == "80661C800"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
        (
            ((pl.col("from_account") == "811C4EDD0") | (pl.col("to_account") == "811C4EDD0")) |
            ((pl.col("from_account") == "812D1AC00") | (pl.col("to_account") == "812D1AC00")) |
            ((pl.col("from_account") == "81235EE30") | (pl.col("to_account") == "81235EE30")) |
            ((pl.col("from_account") == "811E03C30") | (pl.col("to_account") == "811E03C30")) |
            ((pl.col("from_account") == "811EDAA30") | (pl.col("to_account") == "811EDAA30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "8061C8910") | (pl.col("to_account") == "8061C8910")) |
        ((pl.col("from_account") == "803983BE0") | (pl.col("to_account") == "803983BE0")) |
        ((pl.col("from_account") == "80FC0BB60") | (pl.col("to_account") == "80FC0BB60")) |
        ((pl.col("from_account") == "807009D30") | (pl.col("to_account") == "807009D30")) |
        ((pl.col("from_account") == "809A17220") | (pl.col("to_account") == "809A17220")) |
        ((pl.col("from_account") == "805F2B680") | (pl.col("to_account") == "805F2B680")) |
        ((pl.col("from_account") == "80DF70590") | (pl.col("to_account") == "80DF70590")) |
        ((pl.col("from_account") == "80024DDD0") | (pl.col("to_account") == "80024DDD0")) |
        ((pl.col("from_account") == "80A9F95F0") | (pl.col("to_account") == "80A9F95F0")) |
        ((pl.col("from_account") == "80EBC49A0") | (pl.col("to_account") == "80EBC49A0")) |
        ((pl.col("from_account") == "80CC04930") | (pl.col("to_account") == "80CC04930")) |
        ((pl.col("from_account") == "80825B1E0") | (pl.col("to_account") == "80825B1E0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0")) |
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "811C4EDD0") | (pl.col("to_account") == "811C4EDD0")) |
        ((pl.col("from_account") == "811FCA7B0") | (pl.col("to_account") == "811FCA7B0")) |
        ((pl.col("from_account") == "811A67510") | (pl.col("to_account") == "811A67510")) |
        ((pl.col("from_account") == "811ED7DF0") | (pl.col("to_account") == "811ED7DF0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880")) |
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0")) |
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "801D45DD0") | (pl.col("to_account") == "801D45DD0")) |
        ((pl.col("from_account") == "8011422A0") | (pl.col("to_account") == "8011422A0")) |
        ((pl.col("from_account") == "8100C5CC0") | (pl.col("to_account") == "8100C5CC0")) |
        ((pl.col("from_account") == "80B586630") | (pl.col("to_account") == "80B586630"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "800367070") | (pl.col("to_account") == "800367070")) |
        ((pl.col("from_account") == "8025BFA10") | (pl.col("to_account") == "8025BFA10")) |
        ((pl.col("from_account") == "804E13660") | (pl.col("to_account") == "804E13660")) |
        ((pl.col("from_account") == "80D3382E0") | (pl.col("to_account") == "80D3382E0")) |
        ((pl.col("from_account") == "8094423B0") | (pl.col("to_account") == "8094423B0")) |
        ((pl.col("from_account") == "802355E00") | (pl.col("to_account") == "802355E00"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812A09CF0") | (pl.col("to_account") == "812A09CF0")) |
        ((pl.col("from_account") == "812A09D40") | (pl.col("to_account") == "812A09D40"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "810B9DF70") | (pl.col("to_account") == "810B9DF70")) |
        ((pl.col("from_account") == "80E46A430") | (pl.col("to_account") == "80E46A430")) |
        ((pl.col("from_account") == "80E047940") | (pl.col("to_account") == "80E047940")) |
        ((pl.col("from_account") == "8061817B0") | (pl.col("to_account") == "8061817B0")) |
        ((pl.col("from_account") == "801A36EE0") | (pl.col("to_account") == "801A36EE0")) |
        ((pl.col("from_account") == "804A807E0") | (pl.col("to_account") == "804A807E0")) |
        ((pl.col("from_account") == "809894520") | (pl.col("to_account") == "809894520")) |
        ((pl.col("from_account") == "80179A870") | (pl.col("to_account") == "80179A870")) |
        ((pl.col("from_account") == "802308AB0") | (pl.col("to_account") == "802308AB0")) |
        ((pl.col("from_account") == "805ECF470") | (pl.col("to_account") == "805ECF470")) |
        ((pl.col("from_account") == "80DDC5FE0") | (pl.col("to_account") == "80DDC5FE0")) |
        ((pl.col("from_account") == "8007869B0") | (pl.col("to_account") == "8007869B0")) |
        ((pl.col("from_account") == "804703440") | (pl.col("to_account") == "804703440")) |
        ((pl.col("from_account") == "80A504210") | (pl.col("to_account") == "80A504210"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80B0CE170") | (pl.col("to_account") == "80B0CE170")) |
        ((pl.col("from_account") == "80361F020") | (pl.col("to_account") == "80361F020")) |
        ((pl.col("from_account") == "8076E3D00") | (pl.col("to_account") == "8076E3D00")) |
        ((pl.col("from_account") == "804AFC550") | (pl.col("to_account") == "804AFC550")) |
        ((pl.col("from_account") == "802977C20") | (pl.col("to_account") == "802977C20")) |
        ((pl.col("from_account") == "8039A7AD0") | (pl.col("to_account") == "8039A7AD0")) |
        ((pl.col("from_account") == "809880C00") | (pl.col("to_account") == "809880C00")) |
        ((pl.col("from_account") == "801673D80") | (pl.col("to_account") == "801673D80")) |
        ((pl.col("from_account") == "80BA91220") | (pl.col("to_account") == "80BA91220")) |
        ((pl.col("from_account") == "808D935A0") | (pl.col("to_account") == "808D935A0")) |
        ((pl.col("from_account") == "80DE274E0") | (pl.col("to_account") == "80DE274E0")) |
        ((pl.col("from_account") == "811A364F0") | (pl.col("to_account") == "811A364F0")) |
        ((pl.col("from_account") == "80B7390D0") | (pl.col("to_account") == "80B7390D0")) |
        ((pl.col("from_account") == "80590B960") | (pl.col("to_account") == "80590B960")) |
        ((pl.col("from_account") == "8081D5D00") | (pl.col("to_account") == "8081D5D00")) |
        ((pl.col("from_account") == "805368000") | (pl.col("to_account") == "805368000")) |
        ((pl.col("from_account") == "8063DA480") | (pl.col("to_account") == "8063DA480")) |
        ((pl.col("from_account") == "804ED53A0") | (pl.col("to_account") == "804ED53A0")) |
        ((pl.col("from_account") == "80DC8D400") | (pl.col("to_account") == "80DC8D400")) |
        ((pl.col("from_account") == "80EE97110") | (pl.col("to_account") == "80EE97110")) |
        ((pl.col("from_account") == "80860D630") | (pl.col("to_account") == "80860D630")) |
        ((pl.col("from_account") == "8067736B0") | (pl.col("to_account") == "8067736B0")) |
        ((pl.col("from_account") == "8003DF900") | (pl.col("to_account") == "8003DF900")) |
        ((pl.col("from_account") == "809C2F340") | (pl.col("to_account") == "809C2F340"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "800928170") | (pl.col("to_account") == "800928170")) |
        ((pl.col("from_account") == "80B5D7AC0") | (pl.col("to_account") == "80B5D7AC0")) |
        ((pl.col("from_account") == "808F215B0") | (pl.col("to_account") == "808F215B0")) |
        ((pl.col("from_account") == "800BD1990") | (pl.col("to_account") == "800BD1990")) |
        ((pl.col("from_account") == "80CAED3D0") | (pl.col("to_account") == "80CAED3D0")) |
        ((pl.col("from_account") == "80D7E33E0") | (pl.col("to_account") == "80D7E33E0")) |
        ((pl.col("from_account") == "80B3A54F0") | (pl.col("to_account") == "80B3A54F0")) |
        ((pl.col("from_account") == "800A21910") | (pl.col("to_account") == "800A21910")) |
        ((pl.col("from_account") == "804F0BFF0") | (pl.col("to_account") == "804F0BFF0")) |
        ((pl.col("from_account") == "807B0DEE0") | (pl.col("to_account") == "807B0DEE0")) |
        ((pl.col("from_account") == "802583B00") | (pl.col("to_account") == "802583B00")) |
        ((pl.col("from_account") == "80440A040") | (pl.col("to_account") == "80440A040")) |
        ((pl.col("from_account") == "80348E920") | (pl.col("to_account") == "80348E920")) |
        ((pl.col("from_account") == "801A06BB0") | (pl.col("to_account") == "801A06BB0")) |
        ((pl.col("from_account") == "80407D1F0") | (pl.col("to_account") == "80407D1F0")) |
        ((pl.col("from_account") == "808586D90") | (pl.col("to_account") == "808586D90")) |
        ((pl.col("from_account") == "809DDA830") | (pl.col("to_account") == "809DDA830")) |
        ((pl.col("from_account") == "805DF0860") | (pl.col("to_account") == "805DF0860")) |
        ((pl.col("from_account") == "80832C3E0") | (pl.col("to_account") == "80832C3E0")) |
        ((pl.col("from_account") == "803AB9C40") | (pl.col("to_account") == "803AB9C40")) |
        ((pl.col("from_account") == "803249220") | (pl.col("to_account") == "803249220")) |
        ((pl.col("from_account") == "803CEFB70") | (pl.col("to_account") == "803CEFB70")) |
        ((pl.col("from_account") == "80B61F6E0") | (pl.col("to_account") == "80B61F6E0")) |
        ((pl.col("from_account") == "8035A4F50") | (pl.col("to_account") == "8035A4F50")) |
        ((pl.col("from_account") == "80CADC170") | (pl.col("to_account") == "80CADC170")) |
        ((pl.col("from_account") == "80D2D89A0") | (pl.col("to_account") == "80D2D89A0")) |
        ((pl.col("from_account") == "8029821C0") | (pl.col("to_account") == "8029821C0")) |
        ((pl.col("from_account") == "8068B91C0") | (pl.col("to_account") == "8068B91C0")) |
        ((pl.col("from_account") == "80993EAE0") | (pl.col("to_account") == "80993EAE0")) |
        ((pl.col("from_account") == "8019409A0") | (pl.col("to_account") == "8019409A0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "801F46AA0") | (pl.col("to_account") == "801F46AA0")) |
        ((pl.col("from_account") == "805278170") | (pl.col("to_account") == "805278170")) |
        ((pl.col("from_account") == "8129AD010") | (pl.col("to_account") == "8129AD010")) |
        ((pl.col("from_account") == "80C995060") | (pl.col("to_account") == "80C995060")) |
        ((pl.col("from_account") == "80B2F5E60") | (pl.col("to_account") == "80B2F5E60")) |
        ((pl.col("from_account") == "80B438A40") | (pl.col("to_account") == "80B438A40"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "811B6E2B0") | (pl.col("to_account") == "811B6E2B0")) |
        ((pl.col("from_account") == "8119F8CC0") | (pl.col("to_account") == "8119F8CC0")) |
        ((pl.col("from_account") == "811B9B160") | (pl.col("to_account") == "811B9B160")) |
        ((pl.col("from_account") == "8000E1590") | (pl.col("to_account") == "8000E1590")) |
        ((pl.col("from_account") == "811B88600") | (pl.col("to_account") == "811B88600")) |
        ((pl.col("from_account") == "811A00890") | (pl.col("to_account") == "811A00890")) |
        ((pl.col("from_account") == "812D06150") | (pl.col("to_account") == "812D06150")) |
        ((pl.col("from_account") == "814965B00") | (pl.col("to_account") == "814965B00")) |
        ((pl.col("from_account") == "811D80C30") | (pl.col("to_account") == "811D80C30")) |
        ((pl.col("from_account") == "811A65E30") | (pl.col("to_account") == "811A65E30")) |
        ((pl.col("from_account") == "811DCA9B0") | (pl.col("to_account") == "811DCA9B0")) |
        ((pl.col("from_account") == "8000DB3C0") | (pl.col("to_account") == "8000DB3C0")) |
        ((pl.col("from_account") == "811B6E170") | (pl.col("to_account") == "811B6E170")) |
        ((pl.col("from_account") == "800051110") | (pl.col("to_account") == "800051110"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "811EDAA30") | (pl.col("to_account") == "811EDAA30")) |
        ((pl.col("from_account") == "81235EAA0") | (pl.col("to_account") == "81235EAA0")) |
        ((pl.col("from_account") == "811EDA940") | (pl.col("to_account") == "811EDA940")) |
        ((pl.col("from_account") == "812D1A410") | (pl.col("to_account") == "812D1A410")) |
        ((pl.col("from_account") == "8120D4990") | (pl.col("to_account") == "8120D4990")) |
        ((pl.col("from_account") == "811A65E30") | (pl.col("to_account") == "811A65E30")) |
        ((pl.col("from_account") == "811EDA5B0") | (pl.col("to_account") == "811EDA5B0")) |
        ((pl.col("from_account") == "811FCA7B0") | (pl.col("to_account") == "811FCA7B0")) |
        ((pl.col("from_account") == "81235EC40") | (pl.col("to_account") == "81235EC40")) |
        ((pl.col("from_account") == "811ED7DF0") | (pl.col("to_account") == "811ED7DF0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "8030A5760") | (pl.col("to_account") == "8030A5760")) |
        ((pl.col("from_account") == "809900F20") | (pl.col("to_account") == "809900F20")) |
        ((pl.col("from_account") == "8094C64E0") | (pl.col("to_account") == "8094C64E0")) |
        ((pl.col("from_account") == "80D263D60") | (pl.col("to_account") == "80D263D60")) |
        ((pl.col("from_account") == "80ACD8330") | (pl.col("to_account") == "80ACD8330")) |
        ((pl.col("from_account") == "8047CBDA0") | (pl.col("to_account") == "8047CBDA0")) |
        ((pl.col("from_account") == "8036095E0") | (pl.col("to_account") == "8036095E0")) |
        ((pl.col("from_account") == "803724320") | (pl.col("to_account") == "803724320"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "800161D40") | (pl.col("to_account") == "800161D40")) |
        ((pl.col("from_account") == "8000C83D0") | (pl.col("to_account") == "8000C83D0")) |
        ((pl.col("from_account") == "80023F3C0") | (pl.col("to_account") == "80023F3C0")) |
        ((pl.col("from_account") == "800166070") | (pl.col("to_account") == "800166070")) |
        ((pl.col("from_account") == "800207A10") | (pl.col("to_account") == "800207A10")) |
        ((pl.col("from_account") == "8001BFCF0") | (pl.col("to_account") == "8001BFCF0")) |
        ((pl.col("from_account") == "8001BD460") | (pl.col("to_account") == "8001BD460")) |
        ((pl.col("from_account") == "800062E20") | (pl.col("to_account") == "800062E20")) |
        ((pl.col("from_account") == "800526C80") | (pl.col("to_account") == "800526C80")) |
        ((pl.col("from_account") == "800288190") | (pl.col("to_account") == "800288190")) |
        ((pl.col("from_account") == "8000F65C0") | (pl.col("to_account") == "8000F65C0")) |
        ((pl.col("from_account") == "80016FB40") | (pl.col("to_account") == "80016FB40")) |
        ((pl.col("from_account") == "800238830") | (pl.col("to_account") == "800238830")) |
        ((pl.col("from_account") == "8000FE520") | (pl.col("to_account") == "8000FE520")) |
        ((pl.col("from_account") == "8002767B0") | (pl.col("to_account") == "8002767B0")) |
        ((pl.col("from_account") == "800963A90") | (pl.col("to_account") == "800963A90"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "807FF9830") | (pl.col("to_account") == "807FF9830")) |
        ((pl.col("from_account") == "802EAF120") | (pl.col("to_account") == "802EAF120")) |
        ((pl.col("from_account") == "809256DC0") | (pl.col("to_account") == "809256DC0")) |
        ((pl.col("from_account") == "80F972FC0") | (pl.col("to_account") == "80F972FC0")) |
        ((pl.col("from_account") == "803C37930") | (pl.col("to_account") == "803C37930")) |
        ((pl.col("from_account") == "8080F7450") | (pl.col("to_account") == "8080F7450")) |
        ((pl.col("from_account") == "8052E39D0") | (pl.col("to_account") == "8052E39D0")) |
        ((pl.col("from_account") == "8078C8600") | (pl.col("to_account") == "8078C8600")) |
        ((pl.col("from_account") == "80482B5A0") | (pl.col("to_account") == "80482B5A0")) |
        ((pl.col("from_account") == "80A515120") | (pl.col("to_account") == "80A515120")) |
        ((pl.col("from_account") == "80615D270") | (pl.col("to_account") == "80615D270")) |
        ((pl.col("from_account") == "8051AA8E0") | (pl.col("to_account") == "8051AA8E0")) |
        ((pl.col("from_account") == "80187DEC0") | (pl.col("to_account") == "80187DEC0")) |
        ((pl.col("from_account") == "801635F70") | (pl.col("to_account") == "801635F70")) |
        ((pl.col("from_account") == "8083BDEE0") | (pl.col("to_account") == "8083BDEE0")) |
        ((pl.col("from_account") == "804895E90") | (pl.col("to_account") == "804895E90")) |
        ((pl.col("from_account") == "80C4E7410") | (pl.col("to_account") == "80C4E7410")) |
        ((pl.col("from_account") == "800AD9C50") | (pl.col("to_account") == "800AD9C50")) |
        ((pl.col("from_account") == "8035D0FC0") | (pl.col("to_account") == "8035D0FC0")) |
        ((pl.col("from_account") == "80A4273C0") | (pl.col("to_account") == "80A4273C0")) |
        ((pl.col("from_account") == "802403080") | (pl.col("to_account") == "802403080")) |
        ((pl.col("from_account") == "80E765080") | (pl.col("to_account") == "80E765080")) |
        ((pl.col("from_account") == "8058A51E0") | (pl.col("to_account") == "8058A51E0")) |
        ((pl.col("from_account") == "807EE72F0") | (pl.col("to_account") == "807EE72F0")) |
        ((pl.col("from_account") == "8013028A0") | (pl.col("to_account") == "8013028A0")) |
        ((pl.col("from_account") == "803BCC3E0") | (pl.col("to_account") == "803BCC3E0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "80B502BD0") | (pl.col("to_account") == "80B502BD0")) |
        ((pl.col("from_account") == "800E02580") | (pl.col("to_account") == "800E02580")) |
        ((pl.col("from_account") == "80E814F80") | (pl.col("to_account") == "80E814F80")) |
        ((pl.col("from_account") == "805F443D0") | (pl.col("to_account") == "805F443D0")) |
        ((pl.col("from_account") == "802923410") | (pl.col("to_account") == "802923410")) |
        ((pl.col("from_account") == "800373D90") | (pl.col("to_account") == "800373D90")) |
        ((pl.col("from_account") == "80734CB00") | (pl.col("to_account") == "80734CB00")) |
        ((pl.col("from_account") == "80368B680") | (pl.col("to_account") == "80368B680")) |
        ((pl.col("from_account") == "803A62590") | (pl.col("to_account") == "803A62590")) |
        ((pl.col("from_account") == "8006D5E90") | (pl.col("to_account") == "8006D5E90")) |
        ((pl.col("from_account") == "8035FCAE0") | (pl.col("to_account") == "8035FCAE0")) |
        ((pl.col("from_account") == "80ED20E80") | (pl.col("to_account") == "80ED20E80")) |
        ((pl.col("from_account") == "80A3C3F10") | (pl.col("to_account") == "80A3C3F10")) |
        ((pl.col("from_account") == "8060B3D60") | (pl.col("to_account") == "8060B3D60")) |
        ((pl.col("from_account") == "80D715D20") | (pl.col("to_account") == "80D715D20")) |
        ((pl.col("from_account") == "8013BFC10") | (pl.col("to_account") == "8013BFC10")) |
        ((pl.col("from_account") == "8043148C0") | (pl.col("to_account") == "8043148C0")) |
        ((pl.col("from_account") == "80D090CC0") | (pl.col("to_account") == "80D090CC0")) |
        ((pl.col("from_account") == "80BAAEB30") | (pl.col("to_account") == "80BAAEB30")) |
        ((pl.col("from_account") == "80A01B6B0") | (pl.col("to_account") == "80A01B6B0")) |
        ((pl.col("from_account") == "80B1E3F70") | (pl.col("to_account") == "80B1E3F70")) |
        ((pl.col("from_account") == "8063737F0") | (pl.col("to_account") == "8063737F0")) |
        ((pl.col("from_account") == "80D1A92E0") | (pl.col("to_account") == "80D1A92E0")) |
        ((pl.col("from_account") == "806629BE0") | (pl.col("to_account") == "806629BE0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

    .when(
    (
        ((pl.col("from_account") == "812A09D40") | (pl.col("to_account") == "812A09D40")) |
        ((pl.col("from_account") == "812A09CF0") | (pl.col("to_account") == "812A09CF0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "801A42EC0") | (pl.col("to_account") == "801A42EC0")) |
        ((pl.col("from_account") == "80A30B870") | (pl.col("to_account") == "80A30B870")) |
        ((pl.col("from_account") == "80FD68BC0") | (pl.col("to_account") == "80FD68BC0")) |
        ((pl.col("from_account") == "80255DA40") | (pl.col("to_account") == "80255DA40")) |
        ((pl.col("from_account") == "800290ED0") | (pl.col("to_account") == "800290ED0")) |
        ((pl.col("from_account") == "810BCE380") | (pl.col("to_account") == "810BCE380")) |
        ((pl.col("from_account") == "805959900") | (pl.col("to_account") == "805959900")) |
        ((pl.col("from_account") == "805A5EFF0") | (pl.col("to_account") == "805A5EFF0")) |
        ((pl.col("from_account") == "80CD397E0") | (pl.col("to_account") == "80CD397E0")) |
        ((pl.col("from_account") == "80C046B80") | (pl.col("to_account") == "80C046B80")) |
        ((pl.col("from_account") == "80A8ADE10") | (pl.col("to_account") == "80A8ADE10")) |
        ((pl.col("from_account") == "81055E900") | (pl.col("to_account") == "81055E900")) |
        ((pl.col("from_account") == "808ED6360") | (pl.col("to_account") == "808ED6360")) |
        ((pl.col("from_account") == "8027EDAA0") | (pl.col("to_account") == "8027EDAA0")) |
        ((pl.col("from_account") == "803465880") | (pl.col("to_account") == "803465880")) |
        ((pl.col("from_account") == "80B389320") | (pl.col("to_account") == "80B389320")) |
        ((pl.col("from_account") == "80F06C420") | (pl.col("to_account") == "80F06C420")) |
        ((pl.col("from_account") == "80DD442E0") | (pl.col("to_account") == "80DD442E0")) |
        ((pl.col("from_account") == "80C413DF0") | (pl.col("to_account") == "80C413DF0")) |
        ((pl.col("from_account") == "803BF05B0") | (pl.col("to_account") == "803BF05B0")) |
        ((pl.col("from_account") == "805EC6EB0") | (pl.col("to_account") == "805EC6EB0")) |
        ((pl.col("from_account") == "8086E9E70") | (pl.col("to_account") == "8086E9E70")) |
        ((pl.col("from_account") == "802386190") | (pl.col("to_account") == "802386190")) |
        ((pl.col("from_account") == "801EE3CD0") | (pl.col("to_account") == "801EE3CD0")) |
        ((pl.col("from_account") == "808BC5830") | (pl.col("to_account") == "808BC5830")) |
        ((pl.col("from_account") == "808630EB0") | (pl.col("to_account") == "808630EB0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880")) |
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880")) |
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "811FFF630") | (pl.col("to_account") == "811FFF630")) |
        ((pl.col("from_account") == "812D0C3C0") | (pl.col("to_account") == "812D0C3C0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "800115CA0") | (pl.col("to_account") == "800115CA0")) |
        ((pl.col("from_account") == "800116420") | (pl.col("to_account") == "800116420")) |
        ((pl.col("from_account") == "8001FD490") | (pl.col("to_account") == "8001FD490")) |
        ((pl.col("from_account") == "80022F920") | (pl.col("to_account") == "80022F920")) |
        ((pl.col("from_account") == "80012E100") | (pl.col("to_account") == "80012E100")) |
        ((pl.col("from_account") == "800179CC0") | (pl.col("to_account") == "800179CC0")) |
        ((pl.col("from_account") == "800242CC0") | (pl.col("to_account") == "800242CC0")) |
        ((pl.col("from_account") == "80012D760") | (pl.col("to_account") == "80012D760")) |
        ((pl.col("from_account") == "800059440") | (pl.col("to_account") == "800059440")) |
        ((pl.col("from_account") == "800528510") | (pl.col("to_account") == "800528510")) |
        ((pl.col("from_account") == "8002AE7E0") | (pl.col("to_account") == "8002AE7E0")) |
        ((pl.col("from_account") == "8001AE930") | (pl.col("to_account") == "8001AE930")) |
        ((pl.col("from_account") == "80005D3B0") | (pl.col("to_account") == "80005D3B0")) |
        ((pl.col("from_account") == "8001AE2B0") | (pl.col("to_account") == "8001AE2B0")) |
        ((pl.col("from_account") == "80017BE40") | (pl.col("to_account") == "80017BE40")) |
        ((pl.col("from_account") == "8001697D0") | (pl.col("to_account") == "8001697D0")) |
        ((pl.col("from_account") == "80029BA40") | (pl.col("to_account") == "80029BA40")) |
        ((pl.col("from_account") == "8002438B0") | (pl.col("to_account") == "8002438B0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812A70ED0") | (pl.col("to_account") == "812A70ED0")) |
        ((pl.col("from_account") == "812A70E80") | (pl.col("to_account") == "812A70E80"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812D0C3C0") | (pl.col("to_account") == "812D0C3C0")) |
        ((pl.col("from_account") == "812D0C600") | (pl.col("to_account") == "812D0C600"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "800F1D640") | (pl.col("to_account") == "800F1D640")) |
        ((pl.col("from_account") == "806BF3340") | (pl.col("to_account") == "806BF3340")) |
        ((pl.col("from_account") == "800BA98F0") | (pl.col("to_account") == "800BA98F0")) |
        ((pl.col("from_account") == "803631370") | (pl.col("to_account") == "803631370")) |
        ((pl.col("from_account") == "8026E9C90") | (pl.col("to_account") == "8026E9C90")) |
        ((pl.col("from_account") == "80E86ED60") | (pl.col("to_account") == "80E86ED60")) |
        ((pl.col("from_account") == "80E599BD0") | (pl.col("to_account") == "80E599BD0")) |
        ((pl.col("from_account") == "8063038B0") | (pl.col("to_account") == "8063038B0")) |
        ((pl.col("from_account") == "8071D2930") | (pl.col("to_account") == "8071D2930")) |
        ((pl.col("from_account") == "80755E440") | (pl.col("to_account") == "80755E440")) |
        ((pl.col("from_account") == "803F704D0") | (pl.col("to_account") == "803F704D0")) |
        ((pl.col("from_account") == "80E41B370") | (pl.col("to_account") == "80E41B370")) |
        ((pl.col("from_account") == "80EF93140") | (pl.col("to_account") == "80EF93140")) |
        ((pl.col("from_account") == "800AD0530") | (pl.col("to_account") == "800AD0530")) |
        ((pl.col("from_account") == "802BDE290") | (pl.col("to_account") == "802BDE290")) |
        ((pl.col("from_account") == "80970A1E0") | (pl.col("to_account") == "80970A1E0")) |
        ((pl.col("from_account") == "809FF8A10") | (pl.col("to_account") == "809FF8A10")) |
        ((pl.col("from_account") == "80BD6B060") | (pl.col("to_account") == "80BD6B060"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "811FFF630") | (pl.col("to_account") == "811FFF630")) |
        ((pl.col("from_account") == "812D0C600") | (pl.col("to_account") == "812D0C600"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80544C970") | (pl.col("to_account") == "80544C970")) |
        ((pl.col("from_account") == "802D9D740") | (pl.col("to_account") == "802D9D740")) |
        ((pl.col("from_account") == "8000D7130") | (pl.col("to_account") == "8000D7130")) |
        ((pl.col("from_account") == "80DA97DD0") | (pl.col("to_account") == "80DA97DD0")) |
        ((pl.col("from_account") == "809A1A300") | (pl.col("to_account") == "809A1A300")) |
        ((pl.col("from_account") == "80FF51600") | (pl.col("to_account") == "80FF51600")) |
        ((pl.col("from_account") == "8051972F0") | (pl.col("to_account") == "8051972F0")) |
        ((pl.col("from_account") == "80A209200") | (pl.col("to_account") == "80A209200"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80266F880") | (pl.col("to_account") == "80266F880")) |
        ((pl.col("from_account") == "8021353D0") | (pl.col("to_account") == "8021353D0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80AEA5480") | (pl.col("to_account") == "80AEA5480")) |
        ((pl.col("from_account") == "80C4A9230") | (pl.col("to_account") == "80C4A9230")) |
        ((pl.col("from_account") == "80269E400") | (pl.col("to_account") == "80269E400")) |
        ((pl.col("from_account") == "80FF51600") | (pl.col("to_account") == "80FF51600")) |
        ((pl.col("from_account") == "80A3B5EF0") | (pl.col("to_account") == "80A3B5EF0")) |
        ((pl.col("from_account") == "8086D3BD0") | (pl.col("to_account") == "8086D3BD0")) |
        ((pl.col("from_account") == "80B943DB0") | (pl.col("to_account") == "80B943DB0")) |
        ((pl.col("from_account") == "800D50B30") | (pl.col("to_account") == "800D50B30")) |
        ((pl.col("from_account") == "80ABA62A0") | (pl.col("to_account") == "80ABA62A0")) |
        ((pl.col("from_account") == "80AE269B0") | (pl.col("to_account") == "80AE269B0")) |
        ((pl.col("from_account") == "800F1D640") | (pl.col("to_account") == "800F1D640")) |
        ((pl.col("from_account") == "80B445750") | (pl.col("to_account") == "80B445750"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "8041B2490") | (pl.col("to_account") == "8041B2490")) |
        ((pl.col("from_account") == "80235BCC0") | (pl.col("to_account") == "80235BCC0")) |
        ((pl.col("from_account") == "80011FF60") | (pl.col("to_account") == "80011FF60")) |
        ((pl.col("from_account") == "8088B8A90") | (pl.col("to_account") == "8088B8A90")) |
        ((pl.col("from_account") == "8086EB930") | (pl.col("to_account") == "8086EB930")) |
        ((pl.col("from_account") == "8093195F0") | (pl.col("to_account") == "8093195F0")) |
        ((pl.col("from_account") == "807DAC1F0") | (pl.col("to_account") == "807DAC1F0")) |
        ((pl.col("from_account") == "80B712AB0") | (pl.col("to_account") == "80B712AB0")) |
        ((pl.col("from_account") == "802B1AD20") | (pl.col("to_account") == "802B1AD20")) |
        ((pl.col("from_account") == "8029ADDF0") | (pl.col("to_account") == "8029ADDF0")) |
        ((pl.col("from_account") == "80515A830") | (pl.col("to_account") == "80515A830")) |
        ((pl.col("from_account") == "804CF5230") | (pl.col("to_account") == "804CF5230")) |
        ((pl.col("from_account") == "80047AC40") | (pl.col("to_account") == "80047AC40")) |
        ((pl.col("from_account") == "802410130") | (pl.col("to_account") == "802410130")) |
        ((pl.col("from_account") == "802792890") | (pl.col("to_account") == "802792890")) |
        ((pl.col("from_account") == "805EF85E0") | (pl.col("to_account") == "805EF85E0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "80A2BA120") | (pl.col("to_account") == "80A2BA120")) |
        ((pl.col("from_account") == "8006293D0") | (pl.col("to_account") == "8006293D0")) |
        ((pl.col("from_account") == "80C07AA10") | (pl.col("to_account") == "80C07AA10")) |
        ((pl.col("from_account") == "80C9DD950") | (pl.col("to_account") == "80C9DD950")) |
        ((pl.col("from_account") == "800DF30E0") | (pl.col("to_account") == "800DF30E0")) |
        ((pl.col("from_account") == "804D99520") | (pl.col("to_account") == "804D99520")) |
        ((pl.col("from_account") == "80E65F260") | (pl.col("to_account") == "80E65F260")) |
        ((pl.col("from_account") == "80523F8F0") | (pl.col("to_account") == "80523F8F0")) |
        ((pl.col("from_account") == "805FAC670") | (pl.col("to_account") == "805FAC670")) |
        ((pl.col("from_account") == "802F44090") | (pl.col("to_account") == "802F44090")) |
        ((pl.col("from_account") == "8019CA470") | (pl.col("to_account") == "8019CA470")) |
        ((pl.col("from_account") == "802F789E0") | (pl.col("to_account") == "802F789E0")) |
        ((pl.col("from_account") == "80B79F620") | (pl.col("to_account") == "80B79F620")) |
        ((pl.col("from_account") == "8033AD6C0") | (pl.col("to_account") == "8033AD6C0")) |
        ((pl.col("from_account") == "8072C4900") | (pl.col("to_account") == "8072C4900")) |
        ((pl.col("from_account") == "806240640") | (pl.col("to_account") == "806240640")) |
        ((pl.col("from_account") == "804584340") | (pl.col("to_account") == "804584340")) |
        ((pl.col("from_account") == "800425D10") | (pl.col("to_account") == "800425D10"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812A70ED0") | (pl.col("to_account") == "812A70ED0")) |
        ((pl.col("from_account") == "812A70E80") | (pl.col("to_account") == "812A70E80"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812D0C3C0") | (pl.col("to_account") == "812D0C3C0")) |
        ((pl.col("from_account") == "811FFF630") | (pl.col("to_account") == "811FFF630"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))
    .when(
    (
        ((pl.col("from_account") == "812D127D0") | (pl.col("to_account") == "812D127D0")) |
        ((pl.col("from_account") == "812D129C0") | (pl.col("to_account") == "812D129C0"))
    ) &
    (pl.col("is_laundering") == 1)
    ).then(pl.lit(7))

        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 7)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as bipartite: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as bipartite: 528
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 11904     ┆ 80103A420    ┆ 14077   ┆ 802533E40  ┆ 1             ┆ 7       │
# │ 3489      ┆ 80211F620    ┆ 13265   ┆ 8019C6830  ┆ 1             ┆ 7       │
# │ 21745     ┆ 800A75B90    ┆ 1       ┆ 80162B4B0  ┆ 1             ┆ 7       │
# │ 1         ┆ 8010AA4F0    ┆ 12719   ┆ 8015B5F50  ┆ 1             ┆ 7       │
# │ 1         ┆ 800DD9900    ┆ 11157   ┆ 8006F0580  ┆ 1             ┆ 7       │
# │ 1522      ┆ 800587B60    ┆ 2454    ┆ 802679190  ┆ 1             ┆ 7       │
# ...

# %% [markdown]
# ### Random

# %%
trx = trx.with_columns(
    pl.when(
        (
            ((pl.col("from_account") == "81239C5C0") | (pl.col("to_account") == "81239C5C0")) |
            ((pl.col("from_account") == "80C50EE70") | (pl.col("to_account") == "80C50EE70")) |
            ((pl.col("from_account") == "806EE41E0") | (pl.col("to_account") == "806EE41E0")) |
            ((pl.col("from_account") == "8038A9100") | (pl.col("to_account") == "8038A9100")) |
            ((pl.col("from_account") == "80B4D3030") | (pl.col("to_account") == "80B4D3030")) |
            ((pl.col("from_account") == "8016E2C30") | (pl.col("to_account") == "8016E2C30"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))  # RANDOM

    .when(
        (
            ((pl.col("from_account") == "800178CC0") | (pl.col("to_account") == "800178CC0")) |
            ((pl.col("from_account") == "800283B60") | (pl.col("to_account") == "800283B60")) |
            ((pl.col("from_account") == "8001A6140") | (pl.col("to_account") == "8001A6140")) |
            ((pl.col("from_account") == "800202780") | (pl.col("to_account") == "800202780")) |
            ((pl.col("from_account") == "800119810") | (pl.col("to_account") == "800119810")) |
            ((pl.col("from_account") == "8001B0FA0") | (pl.col("to_account") == "8001B0FA0")) |
            ((pl.col("from_account") == "8002A0E00") | (pl.col("to_account") == "8002A0E00")) |
            ((pl.col("from_account") == "800115860") | (pl.col("to_account") == "800115860"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80BC333F0") | (pl.col("to_account") == "80BC333F0")) |
            ((pl.col("from_account") == "8005DB5B0") | (pl.col("to_account") == "8005DB5B0")) |
            ((pl.col("from_account") == "805C64C90") | (pl.col("to_account") == "805C64C90"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80DD3D780") | (pl.col("to_account") == "80DD3D780")) |
            ((pl.col("from_account") == "80DD7E790") | (pl.col("to_account") == "80DD7E790")) |
            ((pl.col("from_account") == "80C8324E0") | (pl.col("to_account") == "80C8324E0")) |
            ((pl.col("from_account") == "80FBC4B50") | (pl.col("to_account") == "80FBC4B50")) |
            ((pl.col("from_account") == "80C8119E0") | (pl.col("to_account") == "80C8119E0")) |
            ((pl.col("from_account") == "802E79D60") | (pl.col("to_account") == "802E79D60")) |
            ((pl.col("from_account") == "800C21050") | (pl.col("to_account") == "800C21050")) |
            ((pl.col("from_account") == "80848B5B0") | (pl.col("to_account") == "80848B5B0")) |
            ((pl.col("from_account") == "802A17140") | (pl.col("to_account") == "802A17140")) |
            ((pl.col("from_account") == "80B302DA0") | (pl.col("to_account") == "80B302DA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "801514540") | (pl.col("to_account") == "801514540")) |
            ((pl.col("from_account") == "80E5B7A20") | (pl.col("to_account") == "80E5B7A20")) |
            ((pl.col("from_account") == "80DE5F6D0") | (pl.col("to_account") == "80DE5F6D0")) |
            ((pl.col("from_account") == "8105FFAD0") | (pl.col("to_account") == "8105FFAD0")) |
            ((pl.col("from_account") == "80D2EC1E0") | (pl.col("to_account") == "80D2EC1E0")) |
            ((pl.col("from_account") == "80C8C6C40") | (pl.col("to_account") == "80C8C6C40")) |
            ((pl.col("from_account") == "80FF1F660") | (pl.col("to_account") == "80FF1F660"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80026DD70") | (pl.col("to_account") == "80026DD70")) |
            ((pl.col("from_account") == "800065CB0") | (pl.col("to_account") == "800065CB0")) |
            ((pl.col("from_account") == "800289800") | (pl.col("to_account") == "800289800")) |
            ((pl.col("from_account") == "80029BCF0") | (pl.col("to_account") == "80029BCF0")) |
            ((pl.col("from_account") == "800283390") | (pl.col("to_account") == "800283390")) |
            ((pl.col("from_account") == "800061E50") | (pl.col("to_account") == "800061E50")) |
            ((pl.col("from_account") == "8001AF3D0") | (pl.col("to_account") == "8001AF3D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    
    .when(
        (
            ((pl.col("from_account") == "80869DF30") | (pl.col("to_account") == "80869DF30")) |
            ((pl.col("from_account") == "803FBD610") | (pl.col("to_account") == "803FBD610")) |
            ((pl.col("from_account") == "8045C0B70") | (pl.col("to_account") == "8045C0B70")) |
            ((pl.col("from_account") == "80070EC40") | (pl.col("to_account") == "80070EC40")) |
            ((pl.col("from_account") == "8064A8D40") | (pl.col("to_account") == "8064A8D40")) |
            ((pl.col("from_account") == "8004BA030") | (pl.col("to_account") == "8004BA030")) |
            ((pl.col("from_account") == "80478F0B0") | (pl.col("to_account") == "80478F0B0")) |
            ((pl.col("from_account") == "807C03B20") | (pl.col("to_account") == "807C03B20")) |
            ((pl.col("from_account") == "800AC3850") | (pl.col("to_account") == "800AC3850")) |
            ((pl.col("from_account") == "801D1E330") | (pl.col("to_account") == "801D1E330")) |
            ((pl.col("from_account") == "805778CA0") | (pl.col("to_account") == "805778CA0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80B95A8D0") | (pl.col("to_account") == "80B95A8D0")) |
            ((pl.col("from_account") == "808946C20") | (pl.col("to_account") == "808946C20")) |
            ((pl.col("from_account") == "8034CAA70") | (pl.col("to_account") == "8034CAA70")) |
            ((pl.col("from_account") == "809E22150") | (pl.col("to_account") == "809E22150")) |
            ((pl.col("from_account") == "8023202B0") | (pl.col("to_account") == "8023202B0")) |
            ((pl.col("from_account") == "803E0FC70") | (pl.col("to_account") == "803E0FC70")) |
            ((pl.col("from_account") == "8087B1360") | (pl.col("to_account") == "8087B1360")) |
            ((pl.col("from_account") == "808B564F0") | (pl.col("to_account") == "808B564F0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "802DF71D0") | (pl.col("to_account") == "802DF71D0")) |
            ((pl.col("from_account") == "80E33A080") | (pl.col("to_account") == "80E33A080"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "810D87E20") | (pl.col("to_account") == "810D87E20")) |
            ((pl.col("from_account") == "80DF47A40") | (pl.col("to_account") == "80DF47A40")) |
            ((pl.col("from_account") == "802748380") | (pl.col("to_account") == "802748380")) |
            ((pl.col("from_account") == "80AC30BC0") | (pl.col("to_account") == "80AC30BC0")) |
            ((pl.col("from_account") == "80E064980") | (pl.col("to_account") == "80E064980")) |
            ((pl.col("from_account") == "8013F90B0") | (pl.col("to_account") == "8013F90B0")) |
            ((pl.col("from_account") == "80D26F0E0") | (pl.col("to_account") == "80D26F0E0")) |
            ((pl.col("from_account") == "80C0D3710") | (pl.col("to_account") == "80C0D3710")) |
            ((pl.col("from_account") == "80AD0E740") | (pl.col("to_account") == "80AD0E740"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "803962650") | (pl.col("to_account") == "803962650")) |
            ((pl.col("from_account") == "80A884F10") | (pl.col("to_account") == "80A884F10")) |
            ((pl.col("from_account") == "808592ED0") | (pl.col("to_account") == "808592ED0")) |
            ((pl.col("from_account") == "8034B0860") | (pl.col("to_account") == "8034B0860")) |
            ((pl.col("from_account") == "807E4A970") | (pl.col("to_account") == "807E4A970")) |
            ((pl.col("from_account") == "80571FD40") | (pl.col("to_account") == "80571FD40")) |
            ((pl.col("from_account") == "80495F410") | (pl.col("to_account") == "80495F410")) |
            ((pl.col("from_account") == "80CD71F30") | (pl.col("to_account") == "80CD71F30")) |
            ((pl.col("from_account") == "800703FD0") | (pl.col("to_account") == "800703FD0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80FEA9150") | (pl.col("to_account") == "80FEA9150")) |
            ((pl.col("from_account") == "8031E6280") | (pl.col("to_account") == "8031E6280")) |
            ((pl.col("from_account") == "80B762660") | (pl.col("to_account") == "80B762660")) |
            ((pl.col("from_account") == "809F92490") | (pl.col("to_account") == "809F92490")) |
            ((pl.col("from_account") == "80A4203B0") | (pl.col("to_account") == "80A4203B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80026ED50") | (pl.col("to_account") == "80026ED50")) |
            ((pl.col("from_account") == "8002785A0") | (pl.col("to_account") == "8002785A0")) |
            ((pl.col("from_account") == "8000F17D0") | (pl.col("to_account") == "8000F17D0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "800139380") | (pl.col("to_account") == "800139380")) |
            ((pl.col("from_account") == "8008B79F0") | (pl.col("to_account") == "8008B79F0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "800D201E0") | (pl.col("to_account") == "800D201E0")) |
            ((pl.col("from_account") == "80A150B90") | (pl.col("to_account") == "80A150B90")) |
            ((pl.col("from_account") == "80848BBA0") | (pl.col("to_account") == "80848BBA0")) |
            ((pl.col("from_account") == "80F1F8550") | (pl.col("to_account") == "80F1F8550")) |
            ((pl.col("from_account") == "809888C90") | (pl.col("to_account") == "809888C90")) |
            ((pl.col("from_account") == "80B92D990") | (pl.col("to_account") == "80B92D990")) |
            ((pl.col("from_account") == "800C15DD0") | (pl.col("to_account") == "800C15DD0")) |
            ((pl.col("from_account") == "801FFD3E0") | (pl.col("to_account") == "801FFD3E0")) |
            ((pl.col("from_account") == "80D3B56B0") | (pl.col("to_account") == "80D3B56B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "804427530") | (pl.col("to_account") == "804427530")) |
            ((pl.col("from_account") == "8064693B0") | (pl.col("to_account") == "8064693B0")) |
            ((pl.col("from_account") == "801EDDAB0") | (pl.col("to_account") == "801EDDAB0")) |
            ((pl.col("from_account") == "80B5B9D40") | (pl.col("to_account") == "80B5B9D40"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80C8841B0") | (pl.col("to_account") == "80C8841B0")) |
            ((pl.col("from_account") == "80B7C97B0") | (pl.col("to_account") == "80B7C97B0")) |
            ((pl.col("from_account") == "801E81890") | (pl.col("to_account") == "801E81890")) |
            ((pl.col("from_account") == "8054913D0") | (pl.col("to_account") == "8054913D0")) |
            ((pl.col("from_account") == "8002F2E90") | (pl.col("to_account") == "8002F2E90")) |
            ((pl.col("from_account") == "804234190") | (pl.col("to_account") == "804234190")) |
            ((pl.col("from_account") == "80362C640") | (pl.col("to_account") == "80362C640")) |
            ((pl.col("from_account") == "80DB2EFC0") | (pl.col("to_account") == "80DB2EFC0")) |
            ((pl.col("from_account") == "804B2E420") | (pl.col("to_account") == "804B2E420")) |
            ((pl.col("from_account") == "80DB1E720") | (pl.col("to_account") == "80DB1E720")) |
            ((pl.col("from_account") == "80A633EB0") | (pl.col("to_account") == "80A633EB0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80C4D47E0") | (pl.col("to_account") == "80C4D47E0")) |
            ((pl.col("from_account") == "80237FFF0") | (pl.col("to_account") == "80237FFF0")) |
            ((pl.col("from_account") == "805067660") | (pl.col("to_account") == "805067660")) |
            ((pl.col("from_account") == "805B50FB0") | (pl.col("to_account") == "805B50FB0")) |
            ((pl.col("from_account") == "809DAE060") | (pl.col("to_account") == "809DAE060")) |
            ((pl.col("from_account") == "80963D200") | (pl.col("to_account") == "80963D200")) |
            ((pl.col("from_account") == "80BA89570") | (pl.col("to_account") == "80BA89570"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "80CE705C0") | (pl.col("to_account") == "80CE705C0")) |
            ((pl.col("from_account") == "80419CF40") | (pl.col("to_account") == "80419CF40")) |
            ((pl.col("from_account") == "80467E970") | (pl.col("to_account") == "80467E970")) |
            ((pl.col("from_account") == "80E8666D0") | (pl.col("to_account") == "80E8666D0")) |
            ((pl.col("from_account") == "80DD5E610") | (pl.col("to_account") == "80DD5E610")) |
            ((pl.col("from_account") == "80FBE30B0") | (pl.col("to_account") == "80FBE30B0")) |
            ((pl.col("from_account") == "8009CB800") | (pl.col("to_account") == "8009CB800")) |
            ((pl.col("from_account") == "805BAB4F0") | (pl.col("to_account") == "805BAB4F0")) |
            ((pl.col("from_account") == "80B449F70") | (pl.col("to_account") == "80B449F70")) |
            ((pl.col("from_account") == "804E6EA20") | (pl.col("to_account") == "804E6EA20")) |
            ((pl.col("from_account") == "8003E2010") | (pl.col("to_account") == "8003E2010")) |
            ((pl.col("from_account") == "8088B1E00") | (pl.col("to_account") == "8088B1E00")) |
            ((pl.col("from_account") == "80B1EA390") | (pl.col("to_account") == "80B1EA390")) |
            ((pl.col("from_account") == "802E6E910") | (pl.col("to_account") == "802E6E910")) |
            ((pl.col("from_account") == "8011E60B0") | (pl.col("to_account") == "8011E60B0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "81054CBF0") | (pl.col("to_account") == "81054CBF0")) |
            ((pl.col("from_account") == "801F08FB0") | (pl.col("to_account") == "801F08FB0")) |
            ((pl.col("from_account") == "8028EFE80") | (pl.col("to_account") == "8028EFE80")) |
            ((pl.col("from_account") == "80C3B78E0") | (pl.col("to_account") == "80C3B78E0")) |
            ((pl.col("from_account") == "8018C8AF0") | (pl.col("to_account") == "8018C8AF0")) |
            ((pl.col("from_account") == "810FD17D0") | (pl.col("to_account") == "810FD17D0")) |
            ((pl.col("from_account") == "8028D6DF0") | (pl.col("to_account") == "8028D6DF0")) |
            ((pl.col("from_account") == "804093380") | (pl.col("to_account") == "804093380")) |
            ((pl.col("from_account") == "811B90FA0") | (pl.col("to_account") == "811B90FA0")) |
            ((pl.col("from_account") == "80A5044A0") | (pl.col("to_account") == "80A5044A0"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "807BB34C0") | (pl.col("to_account") == "807BB34C0")) |
            ((pl.col("from_account") == "80D4023F0") | (pl.col("to_account") == "80D4023F0")) |
            ((pl.col("from_account") == "8092FCDA0") | (pl.col("to_account") == "8092FCDA0")) |
            ((pl.col("from_account") == "8024E3660") | (pl.col("to_account") == "8024E3660"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "800DCD640") | (pl.col("to_account") == "800DCD640")) |
            ((pl.col("from_account") == "802B7F0F0") | (pl.col("to_account") == "802B7F0F0")) |
            ((pl.col("from_account") == "80ABDE970") | (pl.col("to_account") == "80ABDE970")) |
            ((pl.col("from_account") == "809BEDF40") | (pl.col("to_account") == "809BEDF40")) |
            ((pl.col("from_account") == "8092F0090") | (pl.col("to_account") == "8092F0090")) |
            ((pl.col("from_account") == "80598ED20") | (pl.col("to_account") == "80598ED20")) |
            ((pl.col("from_account") == "8054C12F0") | (pl.col("to_account") == "8054C12F0")) |
            ((pl.col("from_account") == "8093EFCC0") | (pl.col("to_account") == "8093EFCC0")) |
            ((pl.col("from_account") == "8000FD100") | (pl.col("to_account") == "8000FD100")) |
            ((pl.col("from_account") == "806ACD410") | (pl.col("to_account") == "806ACD410")) |
            ((pl.col("from_account") == "809FCC180") | (pl.col("to_account") == "809FCC180")) |
            ((pl.col("from_account") == "80AB23890") | (pl.col("to_account") == "80AB23890"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "8096751E0") | (pl.col("to_account") == "8096751E0")) |
            ((pl.col("from_account") == "811C2F680") | (pl.col("to_account") == "811C2F680")) |
            ((pl.col("from_account") == "80934B170") | (pl.col("to_account") == "80934B170")) |
            ((pl.col("from_account") == "806AABF40") | (pl.col("to_account") == "806AABF40")) |
            ((pl.col("from_account") == "804DA4170") | (pl.col("to_account") == "804DA4170")) |
            ((pl.col("from_account") == "805D2D5C0") | (pl.col("to_account") == "805D2D5C0")) |
            ((pl.col("from_account") == "801CCAF30") | (pl.col("to_account") == "801CCAF30")) |
            ((pl.col("from_account") == "80A9B5370") | (pl.col("to_account") == "80A9B5370")) |
            ((pl.col("from_account") == "805874660") | (pl.col("to_account") == "805874660"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "800597E90") | (pl.col("to_account") == "800597E90")) |
            ((pl.col("from_account") == "806954880") | (pl.col("to_account") == "806954880")) |
            ((pl.col("from_account") == "80681D590") | (pl.col("to_account") == "80681D590")) |
            ((pl.col("from_account") == "80F06ABB0") | (pl.col("to_account") == "80F06ABB0")) |
            ((pl.col("from_account") == "80C1843D0") | (pl.col("to_account") == "80C1843D0")) |
            ((pl.col("from_account") == "8096EC6D0") | (pl.col("to_account") == "8096EC6D0")) |
            ((pl.col("from_account") == "80F2E7070") | (pl.col("to_account") == "80F2E7070")) |
            ((pl.col("from_account") == "80A309670") | (pl.col("to_account") == "80A309670")) |
            ((pl.col("from_account") == "8051BABA0") | (pl.col("to_account") == "8051BABA0")) |
            ((pl.col("from_account") == "81211ED00") | (pl.col("to_account") == "81211ED00")) |
            ((pl.col("from_account") == "809787720") | (pl.col("to_account") == "809787720"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))

    .when(
        (
            ((pl.col("from_account") == "800051110") | (pl.col("to_account") == "800051110")) |
            ((pl.col("from_account") == "814965B00") | (pl.col("to_account") == "814965B00")) |
            ((pl.col("from_account") == "8000DB3C0") | (pl.col("to_account") == "8000DB3C0")) |
            ((pl.col("from_account") == "811B9B160") | (pl.col("to_account") == "811B9B160"))
        ) &
        (pl.col("is_laundering") == 1)
    ).then(pl.lit(6))
        
    .otherwise(pl.col("pattern"))
    .alias("pattern")
)

# %%
test = (
    trx
    .filter(pl.col("pattern") == 6)
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Total tagged as random: {len(test)}")
print(f"All are laundering: {test['is_laundering'].sum() == len(test)}")
print(test.head(10))
# Out:
# Total tagged as random: 192
# All are laundering: True
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 48309     ┆ 81239C5C0    ┆ 32564   ┆ 80C50EE70  ┆ 1             ┆ 6       │
# │ 32564     ┆ 80C50EE70    ┆ 4       ┆ 806EE41E0  ┆ 1             ┆ 6       │
# │ 4         ┆ 806EE41E0    ┆ 19593   ┆ 8038A9100  ┆ 1             ┆ 6       │
# │ 19593     ┆ 8038A9100    ┆ 9129    ┆ 80B4D3030  ┆ 1             ┆ 6       │
# │ 9129      ┆ 80B4D3030    ┆ 1420    ┆ 8016E2C30  ┆ 1             ┆ 6       │
# │ 11        ┆ 800178CC0    ┆ 20      ┆ 800283B60  ┆ 1             ┆ 6       │
# ...

# %%
untagged = (
    trx
    .filter(
        (pl.col("is_laundering") == 1) &
        (pl.col("pattern") == -1)
    )
    .select(["from_bank", "from_account", "to_bank", "to_account", "is_laundering", "pattern"])
    .collect()
)

print(f"Laundering transactions with no pattern assigned: {len(untagged)}")
print(untagged.head(10))
# Out:
# Laundering transactions with no pattern assigned: 1945
# shape: (10, 6)
# ┌───────────┬──────────────┬─────────┬────────────┬───────────────┬─────────┐
# │ from_bank ┆ from_account ┆ to_bank ┆ to_account ┆ is_laundering ┆ pattern │
# │ ---       ┆ ---          ┆ ---     ┆ ---        ┆ ---           ┆ ---     │
# │ i64       ┆ str          ┆ i64     ┆ str        ┆ i64           ┆ i32     │
# ╞═══════════╪══════════════╪═════════╪════════════╪═══════════════╪═════════╡
# │ 70        ┆ 100428660    ┆ 1124    ┆ 800825340  ┆ 1             ┆ -1      │
# │ 70        ┆ 100428660    ┆ 11474   ┆ 805B716C0  ┆ 1             ┆ -1      │
# │ 70        ┆ 100428660    ┆ 15980   ┆ 80B39E7B0  ┆ 1             ┆ -1      │
# │ 70        ┆ 100428660    ┆ 113798  ┆ 80DC756E0  ┆ 1             ┆ -1      │
# │ 70        ┆ 100428660    ┆ 32375   ┆ 80E480620  ┆ 1             ┆ -1      │
# │ 231004    ┆ 812EE86F0    ┆ 21940   ┆ 812EE89C0  ┆ 1             ┆ -1      │
# ...

# %%
pattern_counts = (
    trx.select('pattern')
    .group_by('pattern')
    .agg(pl.len().alias('count'))
    .sort('pattern')
    .collect()
)

print(pattern_counts)
# Out:
# shape: (9, 2)
# ┌─────────┬─────────┐
# │ pattern ┆ count   │
# │ ---     ┆ ---     │
# │ i32     ┆ u32     │
# ╞═════════╪═════════╡
# │ -1      ┆ 5075113 │
# │ 0       ┆ 309     │
# │ 1       ┆ 283     │
# │ 2       ┆ 664     │
# │ 3       ┆ 570     │
# │ 4       ┆ 253     │
# │ 5       ┆ 456     │
# │ 6       ┆ 192     │
# │ 7       ┆ 505     │
# └─────────┴─────────┘

# %%
# Verify that all non-laundering transactions have pattern == -1
check = (
    trx.filter(
        (pl.col('is_laundering') == 0) & (pl.col('pattern') != -1)
    )
    .select(pl.len())
    .collect()
    .item()
)

print(f"Non-laundering transactions with a pattern assigned: {check}")
print("OK" if check == 0 else "MISMATCH — investigate")
# Out:
# Non-laundering transactions with a pattern assigned: 0
# OK

# %%
trx.sink_parquet('trx.parquet')
